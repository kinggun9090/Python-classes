# %% [markdown]
# # 🗂️ 파일 입출력 & 예외처리

# %% [markdown]
# ## 📄 파일 입출력 기초
#
# 파일 입출력은 **프로그램과 외부 파일 간의 데이터 교환**을 의미합니다.
#
# ### 파일 열기와 닫기
#
# **기본 문법**
# ```python
# # 파일 열기
# file = open('파일명.txt', '모드')
# # 파일 작업
# file.close()  # 반드시 닫아야 함
#
# ```

# %% [markdown]
# **파일 모드**
#
# - `'r'`: 읽기 (기본값)
# - `'w'`: 쓰기 (기존 내용 덮어쓰기)
# - `'a'`: 추가 (기존 내용 뒤에 추가)
# - `'r+'`: 읽기/쓰기
#
# ### with문 사용 (권장)
#
# **왜 with문을 사용할까?**
#
# - 파일을 자동으로 닫아줌 (메모리 누수 방지)
# - 예외가 발생해도 안전하게 파일 닫기
#
# ```python
# # 권장하는 방법
# # with 블록을 벗어나면 자동으로 file.close() 실행
# with open('example.txt', 'r') as file:
#     content = file.read()
#     print(content)
#
# # 권장하지 않는 방법
# file = open('example.txt', 'r')
# content = file.read()
# print(content)
# file.close()  # 실수로 빠뜨리기 쉬움
#
# ```

# %% [markdown]
# ### 파일 읽기

# %%
# diary.txt 파일 생성
with open('diary.txt', 'w', encoding='utf-8') as file:
    file.write("2024년 8월 22일\n")
    file.write("오늘은 파이썬 파일 입출력을 배웠다.\n")
    file.write("with문을 사용하면 파일이 자동으로 닫힌다.\n")
    file.write("read(), readline(), readlines() 차이점도 알게 되었다.\n")
    file.write("내일은 예외처리를 공부할 예정이다.\n")

# %%
# 1. 전체 내용 읽기
with open('diary.txt', 'r', encoding='utf-8') as file:
    content = file.read()
    print(content)
    print(type(content))
# Out:
# 2024년 8월 22일
# 오늘은 파이썬 파일 입출력을 배웠다.
# with문을 사용하면 파일이 자동으로 닫힌다.
# read(), readline(), readlines() 차이점도 알게 되었다.
# 내일은 예외처리를 공부할 예정이다.
#
# <class 'str'>

# %%
# 2. 첫 번째 줄만 읽기
with open('diary.txt', 'r', encoding='utf-8') as file:
    line = file.readline()
    print(line.strip())
# Out:
# 2024년 8월 22일

# %%
# 3. 모든 줄을 리스트로 읽기
with open('diary.txt', 'r', encoding='utf-8') as file:
    lines = file.readlines()
    for line in lines: # 5번 순회
        print(line.strip())
        print("=" * 30)

    print(len(lines))
# Out:
# 2024년 8월 22일
# ==============================
# 오늘은 파이썬 파일 입출력을 배웠다.
# ==============================
# with문을 사용하면 파일이 자동으로 닫힌다.
# ==============================
# read(), readline(), readlines() 차이점도 알게 되었다.
# ==============================
# 내일은 예외처리를 공부할 예정이다.
# ==============================
# 5

# %%
# 4. for문으로 간단하게 읽기 (권장)
with open('diary.txt', 'r', encoding='utf-8') as file:
    for line in file:
        print(line.strip())
        print("=" * 30)
# Out:
# 2024년 8월 22일
# ==============================
# 오늘은 파이썬 파일 입출력을 배웠다.
# ==============================
# with문을 사용하면 파일이 자동으로 닫힌다.
# ==============================
# read(), readline(), readlines() 차이점도 알게 되었다.
# ==============================
# 내일은 예외처리를 공부할 예정이다.
# ==============================

# %% [markdown]
# ### 파일 쓰기

# %%
# 1. 새 파일 생성 (이미 존재하는경우엔 덮어쓰기)
with open('memo.txt', 'w', encoding='utf-8') as file:
    file.write("첫 번째 메모\n")
    file.write("두 번째 메모\n")

# %%
# 2. 기존 파일에 추가
with open('memo.txt', 'a', encoding='utf-8') as file:
    file.write("세 번째 메모\n")

# %%
# 3. 여러 줄 한번에 쓰기
lines = ["할일 1: 파이썬 공부\n", "할일 2: 운동하기\n", "할일 3: 독서\n"]
with open('todo.txt', 'w', encoding='utf-8') as file:
    file.writelines(lines)

# %%
# 4. 리스트 데이터를 파일로 저장
shopping_list = ['우유', '빵', '계란', '사과']
with open('shopping.txt', 'w', encoding='utf-8') as file:
    for item in shopping_list: # 4번 순회
        file.write(f"{item}\n")

# %% [markdown]
# ### 파일 처리 예제

# %%
# 1. scores라는 파일을 연다 (read)
# 2. readlines로 파일을 리스트로 가져온다

# %%
# 학생 성적 관리 시스템
def save_scores(filename, students_data):
    """학생 성적을 파일에 저장"""
    with open(filename, 'w', encoding='utf-8') as file:
        file.write("이름,수학,영어,과학\n")  # 헤더
        for name, scores in students_data.items():
            line = f"{name},{scores['math']},{scores['english']},{scores['science']}\n"
            file.write(line)

def load_scores(filename):
    """파일에서 학생 성적 불러오기"""
    students = {}
    try:
        with open(filename, 'r', encoding='utf-8') as file:
            lines = file.readlines()
            for line in lines[1:]:  # 헤더 제외
                data = line.strip().split(',')
                name = data[0]
                students[name] = {
                    'math': int(data[1]),
                    'english': int(data[2]),
                    'science': int(data[3])
                }
    except FileNotFoundError:
        print("파일을 찾을 수 없습니다.")
    return students

# %%
# 학생 데이터
students_data = {
    '김철수': {'math': 85, 'english': 92, 'science': 78},
    '이영희': {'math': 90, 'english': 85, 'science': 95}
}

# %%
# 파일 쓰기
save_scores('scores.txt', students_data)

# %%
# 파일 읽기
loaded_data = load_scores('scores.txt')
loaded_data
# Out:
# {'김철수': {'math': 85, 'english': 92, 'science': 78},
#  '이영희': {'math': 90, 'english': 85, 'science': 95}}

# %% [markdown]
# ## ⚠️ 예외처리
#
# 예외처리는 프로그램 실행 중 발생할 수 있는 오류를 미리 예상하고 대비해서, 프로그램이 중단되지 않고 적절히 처리하도록 하는 방법입니다.
#
# - **예외(Exception)**: 프로그램 실행 중에 발생하는 오류
#
# ### try-except 기본 구조
#
# ```python
# # 모든 예외 처리 (가장 기본)
# try:
#     # 오류가 발생할 수 있는 코드
#     위험한_코드()
# except:
#     # 모든 오류를 잡음
#     print("뭔가 오류가 발생했습니다")
#
# ```
#
# ```python
# # 예외 정보 받기
# try:
#     위험한_코드()
# except Exception as e:
#     # 예외 객체를 e로 받아서 사용
#     print(f"오류 발생: {e}")
# ```
#
# ```python
# # 특정 예외 타입 지정
# try:
#     # 오류가 발생할 수 있는 코드
#     위험한_코드()
# except 예외타입:
#     # 오류가 발생했을 때 실행할 코드
#     오류_처리_코드()
#
# ```

# %% [markdown]
# ### 기본 예외처리

# %%
# 예외처리 전

age = int(input("나이를 입력하세요: "))
print(f"당신의 나이는 {age}세입니다.")
# Out:
# 나이를 입력하세요: 안녕
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4142302734.py in <cell line: 0>()
#       1 # 예외처리 전
#       2
# ----> 3 age = int(input("나이를 입력하세요: "))
#       4 print(f"당신의 나이는 {age}세입니다.")
#
# ValueError: invalid literal for int() with base 10: '안녕'

# %%
# 1. 숫자 변환 오류 처리
try:
    age = int(input("나이를 입력하세요: "))
    print(f"당신의 나이는 {age}세입니다.")
except ValueError:
    print("숫자를 입력해주세요!")
# Out:
# 나이를 입력하세요: 안녕
# 숫자를 입력해주세요!

# %%
# 2. 0으로 나누기 오류 처리
try:
    a = 10
    b = int(input("나눌 숫자를 입력하세요: "))
    result = a / b
    print(f"결과: {result}")
except ZeroDivisionError:
    print("0으로 나눌 수 없습니다!")
except ValueError:
    print("숫자를 입력해주세요!")
# Out:
# 나눌 숫자를 입력하세요: 0
# 0으로 나눌 수 없습니다!

# %%
# 3. 여러 예외를 한번에 처리
try:
    numbers = [1, 2, 3]
    index = int(input("인덱스 입력: "))
    print(numbers[index])
except (IndexError, ValueError) as e:
    print(f"오류 발생: {e}")
# Out:
# 인덱스 입력: 5
# 오류 발생: list index out of range

# %% [markdown]
# ### else와 finally

# %%
try:
    file_name = input("파일명 입력: ")
    with open(file_name, 'r') as file:
        content = file.read()
except FileNotFoundError:
    print("파일을 찾을 수 없습니다.")
except PermissionError:
    print("파일 접근 권한이 없습니다.")
else:
    # 예외가 발생하지 않았을 때 실행
    print("파일을 성공적으로 읽었습니다.")
    print(f"파일 내용 길이: {len(content)}자")
finally:
    # 예외 발생 여부와 관계없이 항상 실행
    print("파일 처리를 완료했습니다.")
# Out:
# 파일명 입력: diary.txt
# 파일을 성공적으로 읽었습니다.
# 파일 내용 길이: 125자
# 파일 처리를 완료했습니다.

# %% [markdown]
# ### 파일 관련 예외처리

# %%
def safe_file_read(filename):
    """안전한 파일 읽기 함수"""
    try:
        with open(filename, 'r', encoding='utf-8') as file:
            return file.read()
    except FileNotFoundError:
        print(f"'{filename}' 파일을 찾을 수 없습니다.")
        return None
    except PermissionError:
        print(f"'{filename}' 파일에 접근할 권한이 없습니다.")
        return None
    except UnicodeDecodeError:
        print(f"'{filename}' 파일의 인코딩을 읽을 수 없습니다.")
        return None
    except Exception as e:
        print(f"예상치 못한 오류가 발생했습니다: {e}")
        return None

def safe_file_write(filename, content):
    """안전한 파일 쓰기 함수"""
    try:
        with open(filename, 'w', encoding='utf-8') as file:
            file.write(content)
        print(f"'{filename}' 파일에 성공적으로 저장했습니다.")
        return True
    except PermissionError:
        print(f"'{filename}' 파일에 쓸 권한이 없습니다.")
        return False
    except Exception as e:
        print(f"파일 저장 중 오류 발생: {e}")
        return False

# %%
# 사용 예시
content = safe_file_read('diary.txt')
if content:
    print("파일 내용:", content)

success = safe_file_write('output.txt', "Hello, World!")
if success:
    print("저장 완료!")
# Out:
# 파일 내용: 2024년 8월 22일
# 오늘은 파이썬 파일 입출력을 배웠다.
# with문을 사용하면 파일이 자동으로 닫힌다.
# read(), readline(), readlines() 차이점도 알게 되었다.
# 내일은 예외처리를 공부할 예정이다.
#
# 'output.txt' 파일에 성공적으로 저장했습니다.
# 저장 완료!

# %% [markdown]
# # 📊 데이터 포맷 처리

# %% [markdown]
# ## 🔄 JSON 데이터 처리
#
# **JSON (JavaScript Object Notation)은** 딕셔너리와 리스트 같은 파이썬 데이터를 텍스트 파일로 저장하거나 웹에서 주고받을 때 사용하는 표준 데이터 형식입니다.
#
# ### JSON이란?
#
# - JSON은 `문자열`형식
#
# ```json
# {
#     "name": "김철수",
#     "age": 25,
#     "hobbies": ["독서", "영화감상", "운동"],
#     "address": {
#         "city": "서울",
#         "district": "강남구"
#     },
#     "married": false
# }
#
# ```

# %% [markdown]
# ### Python ↔ JSON 변환

# %% [markdown]
# #### 1. json.dumps() - Python → JSON 문자열

# %%
import json

# 딕셔너리를 JSON 문자열로 변환
student = {
    "name": "김철수",
    "age": 20,
    "subjects": ["수학", "영어", "과학"],
    "scholarship": True,
    "gpa": 3.8
}

# JSON 문자열로 변환
json_string = json.dumps(
   student,                # JSON으로 변환할 파이썬 객체
   ensure_ascii=False,     # 한글 등 비ASCII 문자를 유니코드 그대로 출력
   indent=2                # JSON을 2칸 들여쓰기로 예쁘게 포맷팅
)

print(json_string)
print(type(json_string))
# Out:
# {
#   "name": "김철수",
#   "age": 20,
#   "subjects": [
#     "수학",
#     "영어",
#     "과학"
#   ],
#   "scholarship": true,
#   "gpa": 3.8
# }
# <class 'str'>

# %% [markdown]
# - **`ensure_ascii=False`**: 한글 "김철수"로 저장 (True면 "\uc0ac\ub78c" 형태)

# %% [markdown]
# #### 2. json.loads() - JSON 문자열 → Python

# %%
# JSON 문자열을 Python 객체로 변환
json_data = '''
{
    "product": "노트북",
    "price": 1200000,
    "specs": {
        "cpu": "Intel i7",
        "ram": "16GB",
        "storage": "512GB SSD"
    },
    "in_stock": true
}
'''

product = json.loads(json_data)
print(product)  # 딕셔너리로 변환됨
print(type(product))
# Out:
# {'product': '노트북', 'price': 1200000, 'specs': {'cpu': 'Intel i7', 'ram': '16GB', 'storage': '512GB SSD'}, 'in_stock': True}
# <class 'dict'>

# %%
# 데이터 접근
print(f"제품명: {product['product']}")
print(f"가격: {product['price']:,}원")
print(f"CPU: {product['specs']['cpu']}")
# Out:
# 제품명: 노트북
# 가격: 1,200,000원
# CPU: Intel i7

# %% [markdown]
# **Python 데이터타입과 JSON 대응**
#
# - `dict` ↔ `{}`
# - `list` ↔ `[]`
# - `str` ↔ `"string"`
# - `int`, `float` ↔ `number`
# - `True/False` ↔ `true/false`
# - `None` ↔ `null`

# %% [markdown]
# ### 파일에 JSON 저장하고 불러오기

# %% [markdown]
# #### json.dump() - 파일에 저장

# %%
# 학생 데이터
students = [
    {
        "id": 1,
        "name": "김철수",
        "age": 20,
        "major": "컴퓨터공학",
        "scores": {"math": 85, "english": 92, "science": 78}
    },
    {
        "id": 2,
        "name": "이영희",
        "age": 19,
        "major": "경영학",
        "scores": {"math": 90, "english": 85, "science": 95}
    }
]

# %%
import json

# JSON 파일로 저장
with open('students.json', 'w', encoding='utf-8') as file:
    json.dump(
        students,              # 저장할 Python 데이터
        file,                  # 저장할 파일 객체
        ensure_ascii=False,    # 한글 등 비ASCII 문자를 그대로 저장 (True시  "\uc0ac\ub78c"로 변환)
        indent=2               # 들여쓰기 2칸으로 예쁘게 정렬 (None시 한줄로 압축)
    )

print("students.json 파일로 저장 완료!")
# Out:
# students.json 파일로 저장 완료!

# %% [markdown]
# #### json.load() - 파일에서 불러오기

# %%
# JSON 파일에서 데이터 불러오기
try:
    with open('students.json', 'r', encoding='utf-8') as file:
        loaded_students = json.load(file)

    print("불러온 학생 데이터:")
    for student in loaded_students:
        print(f"- {student['name']} ({student['major']})")
        avg_score = sum(student['scores'].values()) / len(student['scores'])
        print(f"  평균 점수: {avg_score:.1f}점")

except FileNotFoundError:
    print("students.json 파일을 찾을 수 없습니다.")
except json.JSONDecodeError:
    print("JSON 파일 형식이 올바르지 않습니다.")
# Out:
# 불러온 학생 데이터:
# - 김철수 (컴퓨터공학)
#   평균 점수: 85.0점
# - 이영희 (경영학)
#   평균 점수: 90.0점

# %% [markdown]
# #### 맛집데이터 API활용

# %%
import requests
import json

url = 'https://www.bluer.co.kr/api/v1/restaurants?page=0&size=30&query=&foodType=&foodTypeDetail=&feature=&location=&locationDetail=&area=&areaDetail=&priceRange=&ribbonType=&recommended=false&isSearchName=false&tabMode=single&searchMode=ribbonType&zone1=&zone2=&zone2Lat=&zone2Lng='
response = requests.get(url)
response.content # 응답 데이터
# Out:
# b'{\n  "_embedded" : {\n    "restaurants" : [ {\n      "createdDate" : 1441599162000,\n      "id" : 28229,\n      "headerInfo" : {\n        "nameKR" : "\xec\x95\x8c\xeb\x9d\xbc\xed\x94\x84\xeb\xa6\xac\xeb\xa7\x88",\n        "nameEN" : "alla prima",\n        "nameCN" : "",\n        "bookYear" : "2025",\n        "ribbonType" : "RIBBON_THREE",\n        "ribbonTypeByOrdinal" : 0\n      },\n      "defaultInfo" : {\n        "chefName" : "\xea\xb9\x80\xec\xa7\x84\xed\x98\x81",\n        "website" : "https://allaprima.co.kr/",\n        "websiteInstagram" : "https://www.instagram.com/restaurant_allaprima/",\n        "websiteFacebook" : "",\n        "phone" : "02-511-2555 ",\n        "websiteStore" : "",\n        "websiteReserveNaver" : "",\n        "websiteReserveCatch" : "",\n        "websiteReserveOther" : ""\n      },\n      "statusInfo" : {\n        "storeType" : "NOT",\n        "parkingType" : "VALET",\n        "parking" : "",\n        "creditCard" : "y",\n        "visit" : "\xeb\x85\xbc\xed\x98\x84\xec\x97\xad 7\xeb\xb2\x88 \xec\xb6\x9c\xea\xb5\xac\xec\x97\x90\xec\x84\x9c \xec\xb2\xab \xeb\xb2\x88\xec\xa7\xb8 \xea\xb3\xa8\xeb\xaa\xa9\xec\x9c\xbc\xeb\xa1\x9c \xec\x9a\xb0\xed\x9a\x8c\xec\xa0\x84 \xed\x9b\x84 \xed\x95\x99\xeb\x8f\x99\xec\x97\xad \xeb\xb0\xa9\xed\x96\xa5\xec\x9c\xbc\xeb\xa1\x9c \xec\xa7\x81\xec\xa7\x84\xed\x95\x98\xeb\xa9\xb4 \xec\xa2\x8c\xec\xb8\xa1",\n        "priceRangeMin" : 190000,\n        "priceRangeMax" : 310000,\n        "openDate" : "201507",\n        "openEra" : "",\n        "businessHours" : "",\n        "menu" : "",\n        "dayOff" : "",\n        "newOpenDate" : "2015\xeb\x85\x84 07\xec\x9b\x94 "\n      },\n      "juso" : {\n        "detailAddress" : "",\n        "roadAddrPart1" : "\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c \xea\xb0\x95\xeb\x82\xa8\xea\xb5\xac \xed\x95\x99\xeb\x8f\x99\xeb\xa1\x9c17\xea\xb8\xb8 13",\n        "roadAddrPart2" : "(\xeb\x85\xbc\xed\x98\x84\xeb\x8f\x99)",\n        "jibunAddr" : "\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c \xea\xb0\x95\xeb\x82\xa8\xea\xb5\xac \xeb\x85\xbc\xed\x98\x84\xeb\x8f\x99 42-6 \xec\x9d\xb8\xeb\xb3\xb8",\n        "engAddr" : "13, Hakdong-ro 17-gil, Gangnam-gu, Seoul",\n        "zipNo" : "06045",\n        "admCd" : "1168010800",\n        "detBdNmList" : "",\n        "bdNm" : "\xec\x9d\xb8\xeb\xb3\xb8",\n        "siNm" : "\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c",\n        "sggNm" : "\xea\xb0\x95\xeb\x82\xa8\xea\xb5\xac",\n        "emdNm" : "\xeb\x85\xbc\xed\x98\x84\xeb\x8f\x99",\n        "liNm" : "",\n        "rn" : "\xed\x95\x99\xeb\x8f\x99\xeb\xa1\x9c17\xea\xb8\xb8",\n        "buldMnnm" : "13",\n        "buldSlno" : "0",\n        "zone2_1" : "\xec\x84\x9c\xec\x9a\xb8 \xea\xb0\x95\xeb\x82\xa8",\n        "zone2_2" : "\xeb\x85\xbc\xed\x98\x84\xeb\x8f\x99/\xec\x98\x81\xeb\x8f\x99\xec\x8b\x9c\xec\x9e\xa5",\n        "map_1" : "\xec\x84\x9c\xec\x9a\xb8 \xea\xb0\x95\xeb\x82\xa8\xec\xa7\x80\xec\x97\xad",\n        "map_2" : "\xe2\x84\x93. \xeb\x85\xbc\xed\x98\x84\xec\x97\xad-\xea\xb5\x90\xeb\xb3\xb4\xed\x83\x80\xec\x9b\x8c\xec\x82\xac\xea\xb1\xb0\xeb\xa6\xac"\n      },\n      "gps" : {\n        "latitude" : 37.513525,\n        "longitude" : 127.026005\n      },\n      "review" : {\n        "review" : "\xec\x9e\xac\xed\x8c\xa8\xeb\x8b\x88\xec\xa6\x88\xec\x9d\x98 \xec\x98\x81\xed\x96\xa5\xec\x9d\x84 \xeb\xb0\x9b\xec\x9d\x80 \xec\xbb\xa8\xed\x85\x9c\xed\x8f\xac\xeb\x9f\xac\xeb\xa6\xac \xec\x9c\xa0\xeb\xa1\x9c\xed\x94\xbc\xec\x95\x88 \xeb\xa0\x88\xec\x8a\xa4\xed\x86\xa0\xeb\x9e\x91\xec\x9c\xbc\xeb\xa1\x9c, \xea\xb9\x80\xec\xa7\x84\xed\x98\x81 \xec\x85\xb0\xed\x94\x84\xea\xb0\x80 \xec\xa3\xbc\xeb\xb0\xa9\xec\x9d\x84 \xeb\xa7\xa1\xea\xb3\xa0 \xec\x9e\x88\xeb\x8b\xa4. \xed\x85\x8c\xec\x9d\xb4\xec\x8a\xa4\xed\x8c\x85 \xeb\xa9\x94\xeb\x89\xb4\xeb\xa1\x9c \xec\x9d\xb4\xeb\xa3\xa8\xec\x96\xb4\xec\xa7\x84 \xec\xbd\x94\xec\x8a\xa4\xeb\x8a\x94 \xec\x88\x98\xec\x8b\x9c\xeb\xa1\x9c \xea\xb5\xac\xec\x84\xb1\xec\x9d\xb4 \xeb\x ...

# %%
data = json.loads(response.content)
print(type(data))
# Out:
# <class 'dict'>

# %%
data
# Out:
# {'_embedded': {'restaurants': [{'createdDate': 1441599162000,
#     'id': 28229,
#     'headerInfo': {'nameKR': '알라프리마',
#      'nameEN': 'alla prima',
#      'nameCN': '',
#      'bookYear': '2025',
#      'ribbonType': 'RIBBON_THREE',
#      'ribbonTypeByOrdinal': 0},
#     'defaultInfo': {'chefName': '김진혁',
#      'website': 'https://allaprima.co.kr/',
#      'websiteInstagram': 'https://www.instagram.com/restaurant_allaprima/',
#      'websiteFacebook': '',
#      'phone': '02-511-2555 ',
#      'websiteStore': '',
#      'websiteReserveNaver': '',
#      'websiteReserveCatch': '',
#      'websiteReserveOther': ''},
#     'statusInfo': {'storeType': 'NOT',
#      'parkingType': 'VALET',
#      'parking': '',
#      'creditCard': 'y',
#      'visit': '논현역 7번 출구에서 첫 번째 골목으로 우회전 후 학동역 방향으로 직진하면 좌측',
#      'priceRangeMin': 190000,
#      'priceRangeMax': 310000,
#      'openDate': '201507',
#      'openEra': '',
#      'businessHours': '',
#      'menu': '',
#      'dayOff': '',
#      'newOpenDate': '2015년 07월 '},
#     'juso': {'detailAddress': '',
#      'roadAddrPart1': '서울특별시 강남구 학동로17길 13',
#      'roadAddrPart2': '(논현동)',
#      'jibunAddr': '서울특별시 강남구 논현동 42-6 인본',
#      'engAddr': '13, Hakdong-ro 17-gil, Gangnam-gu, Seoul',
#      'zipNo': '06045',
#      'admCd': '1168010800',
#      'detBdNmList': '',
#      'bdNm': '인본',
#      'siNm': '서울특별시',
#      'sggNm': '강남구',
#      'emdNm': '논현동',
#      'liNm': '',
#      'rn': '학동로17길',
#      'buldMnnm': '13',
#      'buldSlno': '0',
#      'zone2_1': '서울 강남',
#      'zone2_2': '논현동/영동시장',
#      'map_1': '서울 강남지역',
#      'map_2': 'ℓ. 논현역-교보타워사거리'},
#     'gps': {'latitude': 37.513525, 'longitude': 127.026005},
#     'review': {'review': '재패니즈의 영향을 받은 컨템포러리 유로피안 레스토랑으로, 김진혁 셰프가 주방을 맡고 있다. 테이스팅 메뉴로 이루어진 코스는 수시로 구성이 바뀌어 셰프의 감각을 엿볼 수 있다. 블랙톤의 세련된 인테리어에 널찍한 공간이 쾌적한 느낌을 준다.',
#      'reviewSimple': '재패니즈의 영향을 받은 컨템포러리 유로피안 레스토랑으로, 김진혁 셰프가 주방을 맡고 있다. 테이스팅 메뉴로 이루어진 코스는 수시로 구성이 바뀌어 셰프의 감각을 엿볼 수 있다. 블랙톤의 세련된 인테리어에 널찍한 공간이 쾌적한 느낌을 준다.',
#      'readerReview': '',
#      'businessReview': ''},
#     'extraInfo': {'wineInputType': 'NO_CHECK',
#      'wineInputYesEtc': '',
#      'wineCorkageEtc': '',
#      'holidayYn': True,
#      'wineOrderYn': False,
#      'holidayType': 'FESTIVAL',
#      'holidayEtc': '',
#      'timeEtc': ''},
#     'tags': '',
#     'etcInfo': {'interior': '',
#      'seat': '',
#      'room': '',
#      'toilet': None,
#      'toiletEtc': '',
#      'chain': False,
#      'close': False,
#      'renewal': False,
#      'reviewerRecommend': False,
#      'onlySiteView': False,
#      'head': '',
#      'branch': ''},
#     'status': 'ACTIVE',
#     'buzUsername': '',
#     'brandMatchStatus': 'NORMAL',
#     'brandRejectReason': '',
#     'orderDescending': 0,
#     'foodTypeDetails': None,
#     'features': None,
#     'countEvaluate': 0,
#     'bookmark': False,
#     'workingHour': '오늘 휴무일',
#     'hourInfoBreakEnd2Times': None,
#     'foodTypes': ['컨템포러리'],
#     'foodDetailTypes': ['컨템포러리'],
#     'feature107': False,
#     'brandBranches': [],
#     'expiredBusinessDate': True,
#     'brandHead': None,
#     'firstImage': {'createdDate': 1755615280000,
#      'url': '/images/es_aabd9516c7d74cdbbda6b062504b430c.jpg',
#      'orderAscending': 0},
#     'firstLogoImage': None,
#     '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28229'},
#      'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28229{?projection}',
#       'templated': True},
#      'childrenRestaurants': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28229/childrenRestaurants{?projection}',
#       'templated': True},
#      'holidayList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28229/holidayList'},
#      'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28229/relativeWriter'},
#      'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28229/evaluates'},
#      'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28229/restaurantFeatures'},
#      'menuList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28229/menuList'},
#      'businessOrders': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28229/businessOrders'},
#      'wineList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28229/wineList'},
#      'hourList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28229/hourList'},
#      'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28229/reports'},
#      'parentRestaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28229/parentRestaurant{?projection}',
#       'templated': True},
#      'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28229/foodTypeCategories'}}},
#    {'createdDate': 1473657935000,
#     'id': 28946,
#     'headerInfo': {'nameKR': '더그린테이블',
#      'nameEN': 'The Green Table',
#      'nameCN': '',
#      'bookYear': '2025',
#      'ribbonType': 'RIBBON_THREE',
#      'ribbonTypeByOrdinal': 0},
#     'defaultInfo': {'chefName': '김은희',
#      'website': 'http://thegreentable.co.kr/',
#      'websiteInstagram': 'https://www.instagram.com/restaurant_thegreentable/',
#      'websiteFacebook': '',
#      'phone': '02-591-2672',
#      'websiteStore': '',
#      'websiteReserveNaver': '',
#      'websiteReserveCatch': '',
#      'websiteReserveOther': ''},
#     'statusInfo': {'storeType': 'NOT',
#      'parkingType': 'YES',
#      'parking': '',
#      'creditCard': 'y',
#      'visit': '안국역 3번 출구에서 직진 후 아라리오 뮤지엄 5층에 위치',
#      'priceRangeMin': 170000,
#      'priceRangeMax': 270000,
#      'openDate': '20091114',
#      'openEra': '',
#      'businessHours': '',
#      'menu': '',
#      'dayOff': '',
#      'newOpenDate': '2009년 11월 14일'},
#     'juso': {'detailAddress': '아라리오 뮤지엄 5층',
#      'roadAddrPart1': '서울특별시 종로구 율곡로 83',
#      'roadAddrPart2': ' (원서동)',
#      'jibunAddr': '서울특별시 종로구 원서동 219',
#      'engAddr': '83 Yulgok-ro, Jongno-gu, Seoul',
#      'zipNo': '03058',
#      'admCd': '1111014900',
#      'detBdNmList': '',
#      'bdNm': '',
#      'siNm': '서울특별시',
#      'sggNm': '종로구',
#      'emdNm': '원서동',
#      'liNm': '',
#      'rn': '',
#      'buldMnnm': '83',
#      'buldSlno': '0',
#      'zone2_1': '서울 강북',
#      'zone2_2': '삼청동/안국동/북촌',
#      'map_1': '서울 강북지역',
#      'map_2': 'L. 삼청동-북촌'},
#     'gps': {'latitude': 37.5777621971432, 'longitude': 126.988357552948},
#     'review': {'review': '김은희 셰프가 운영하는 프렌치 레스토랑. 사계절에 따라 변화하는 우리나라 식재료로 만든 프렌치 요리를 선보인다. 제철 나물, 곡물, 생선, 해산물 등을 활용한 요리에서 변화하는 식재료의 다채로움을 즐길 수 있다. 멋진 창덕궁 뷰를 감상하며 분위기 있는 식사를 할 수 있는 곳이다.',
#      'reviewSimple': '김은희 셰프가 운영하는 프렌치 레스토랑. 사계절에 따라 변화하는 우리나라 식재료로 만든 프렌치 요리를 선보인다. 제철 나물, 곡물, 생선, 해산물 등을 활용한 요리에서 변화하는 식재료의 다채로움을 즐길 수 있다. 멋진 창덕궁 뷰를 감상하며 분위기 있는 식사를 즐길 수 있다.',
#      'readerReview': '',
#      'businessReview': ''},
#     'extraInfo': {'wineInputType': 'NO_CHECK',
#      'wineInputYesEtc': '',
#      'wineCorkageEtc': '',
#      'holidayYn': True,
#      'wineOrderYn': False,
#      'holidayType': 'FESTIVAL',
#      'holidayEtc': '',
#      'timeEtc': ''},
#     'tags': '',
#     'etcInfo': {'interior': '',
#      'seat': '',
#      'room': '',
#      'toilet': None,
#      'toiletEtc': '',
#      'chain': False,
#      'close': False,
#      'renewal': False,
#      'reviewerRecommend': False,
#      'onlySiteView': False,
#      'head': '',
#      'branch': ''},
#     'status': 'ACTIVE',
#     'buzUsername': '',
#     'brandMatchStatus': 'NORMAL',
#     'brandRejectReason': '',
#     'orderDescending': 0,
#     'foodTypeDetails': None,
#     'features': None,
#     'countEvaluate': 0,
#     'bookmark': False,
#     'workingHour': '오늘 휴무일',
#     'hourInfoBreakEnd2Times': None,
#     'foodTypes': ['프랑스식'],
#     'foodDetailTypes': ['프랑스식'],
#     'feature107': True,
#     'brandBranches': [],
#     'expiredBusinessDate': True,
#     'brandHead': None,
#     'firstImage': {'createdDate': 1755156910000,
#      'url': '/images/es_fa44cbc809704ba88bc2f8cba3bb7da4.jpg',
#      'orderAscending': 0},
#     'firstLogoImage': None,
#     '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28946'},
#      'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28946{?projection}',
#       'templated': True},
#      'childrenRestaurants': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28946/childrenRestaurants{?projection}',
#       'templated': True},
#      'holidayList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28946/holidayList'},
#      'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28946/relativeWriter'},
#      'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28946/evaluates'},
#      'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28946/restaurantFeatures'},
#      'menuList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28946/menuList'},
#      'businessOrders': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28946/businessOrders'},
#      'wineList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28946/wineList'},
#      'hourList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28946/hourList'},
#      'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28946/reports'},
#      'parentRestaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28946/parentRestaurant{?projection}',
#       'templated': True},
#      'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28946/foodTypeCategories'}}},
#    {'createdDate': 1491979311000,
#     'id': 29083,
#     'headerInfo': {'nameKR': '쵸이닷',
#      'nameEN': 'CHOI.',
#      'nameCN': '',
#      'bookYear': '2025',
#      'ribbonType': 'RIBBON_THREE',
#      'ribbonTypeByOrdinal': 0},
#     'defaultInfo': {'chefName': '최현석',
#      'website': 'https://choidot.imweb.me/',
#      'websiteInstagram': 'https://www.instagram.com/choidot_official/',
#      'websiteFacebook': '',
#      'phone': '02-518-0318',
#      'websiteStore': '',
#      'websiteReserveNaver': '',
#      'websiteReserveCatch': '',
#      'websiteReserveOther': ''},
#     'statusInfo': {'storeType': 'NOT',
#      'parkingType': 'VALET',
#      'parking': '',
#      'creditCard': 'y',
#      'visit': '청담사거리 앞. 버버리코리아 옆 건물',
#      'priceRangeMin': 78000,
#      'priceRangeMax': 198000,
#      'openDate': '20170318',
#      'openEra': '',
#      'businessHours': '',
#      'menu': '',
#      'dayOff': '',
#      'newOpenDate': '2017년 03월 18일'},
#     'juso': {'detailAddress': '앙스돔빌딩 3층',
#      'roadAddrPart1': '서울특별시 강남구 도산대로 457',
#      'roadAddrPart2': '(청담동)',
#      'jibunAddr': '서울특별시 강남구 청담동 98-7 앙스돔빌딩',
#      'engAddr': '457, Dosan-daero, Gangnam-gu, Seoul',
#      'zipNo': '06015',
#      'admCd': '1168010400',
#      'detBdNmList': '',
#      'bdNm': '앙스돔빌딩',
#      'siNm': '서울특별시',
#      'sggNm': '강남구',
#      'emdNm': '청담동',
#      'liNm': '',
#      'rn': '',
#      'buldMnnm': '457',
#      'buldSlno': '0',
#      'zone2_1': '서울 강남',
#      'zone2_2': '청담동/강남구청역',
#      'map_1': '서울 강남지역',
#      'map_2': ''},
#     'gps': {'latitude': 37.524456, 'longitude': 127.046528},
#     'review': {'review': '최현석 셰프의 크리에이티브한 요리를 즐길 수 있는 레스토랑. 분자요리와 이탈리아 요리를 기반으로 한 창의적인 요리가 코스로 나온다. 생각지 못한 재기발랄한 플레이팅은 자칫 엄숙하게 느껴질 수 있는 파인다이닝에 위트로 작용한다. 메뉴는 계절이나 재료에 맞춰 주기적으로 바뀌며 요리에 걸맞은 와인을 곁들이는 와인페어링도 추천한다. ',
#      'reviewSimple': '최현석 셰프의 크리에이티브한 요리를 즐길 수 있는 레스토랑. 분자요리와 이탈리아 요리를 기반으로 한 창의적인 요리가 코스로 나온다. 생각지 못한 재기발랄한 플레이팅은 자칫 엄숙하게 느껴질 수 있는 파인다이닝에 위트로 작용한다. 메뉴는 계절이나 재료에 맞춰 주기적으로 바뀌며 요리에 걸맞은 와인을 곁들이는 와인페어링도 추천한다.',
#      'readerReview': '',
#      'businessReview': ''},
#     'extraInfo': {'wineInputType': 'NO_CHECK',
#      'wineInputYesEtc': '',
#      'wineCorkageEtc': '',
#      'holidayYn': False,
#      'wineOrderYn': False,
#      'holidayType': 'HOLIDAY_NOT',
#      'holidayEtc': '',
#      'timeEtc': ''},
#     'tags': '흑백요리사',
#     'etcInfo': {'interior': '',
#      'seat': '',
#      'room': '',
#      'toilet': None,
#      'toiletEtc': '',
#      'chain': False,
#      'close': False,
#      'renewal': False,
#      'reviewerRecommend': False,
#      'onlySiteView': False,
#      'head': '',
#      'branch': ''},
#     'status': 'ACTIVE',
#     'buzUsername': '',
#     'brandMatchStatus': 'NORMAL',
#     'brandRejectReason': '',
#     'orderDescending': 0,
#     'foodTypeDetails': None,
#     'features': None,
#     'countEvaluate': 0,
#     'bookmark': False,
#     'workingHour': '현재 브레이크 타임<br/>18:30부터 영업 시작',
#     'hourInfoBreakEnd2Times': None,
#     'foodTypes': ['컨템포러리', '이노베이티브퀴진', '분자요리', '이탈리아식'],
#     'foodDetailTypes': ['이노베이티브퀴진', '분자요리', '이탈리아식'],
#     'feature107': True,
#     'brandBranches': [],
#     'expiredBusinessDate': True,
#     'brandHead': None,
#     'firstImage': {'createdDate': 1754983881000,
#      'url': '/images/es_d0546f2b0dd749b69a128dd78c9bba9b.jpg',
#      'orderAscending': 0},
#     'firstLogoImage': None,
#     '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29083'},
#      'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29083{?projection}',
#       'templated': True},
#      'childrenRestaurants': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29083/childrenRestaurants{?projection}',
#       'templated': True},
#      'holidayList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29083/holidayList'},
#      'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29083/relativeWriter'},
#      'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29083/evaluates'},
#      'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29083/restaurantFeatures'},
#      'menuList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29083/menuList'},
#      'businessOrders': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29083/businessOrders'},
#      'wineList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29083/wineList'},
#      'hourList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29083/hourList'},
#      'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29083/reports'},
#      'parentRestaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29083/parentRestaurant{?projection}',
#       'templated': True},
#      'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29083/foodTypeCategories'}}},
#    {'createdDate': 1507612109000,
#     'id': 29243,
#     'headerInfo': {'nameKR': '무오키',
#      'nameEN': 'MUOKI',
#      'nameCN': '',
#      'bookYear': '2025',
#      'ribbonType': 'RIBBON_THREE',
#      'ribbonTypeByOrdinal': 0},
#     'defaultInfo': {'chefName': '박무현',
#      'website': '',
#      'websiteInstagram': 'https://www.instagram.com/muoki.seoul/',
#      'websiteFacebook': '',
#      'phone': '010-2948-4171',
#      'websiteStore': '',
#      'websiteReserveNaver': '',
#      'websiteReserveCatch': '',
#      'websiteReserveOther': ''},
#     'statusInfo': {'storeType': 'NOT',
#      'parkingType': 'VALET',
#      'parking': '',
#      'creditCard': 'y',
#      'visit': '강남구청역 4번 출구에서 첫 번째 골목으로 좌회전. 디자인치과 옆 골목으로 직진하면 우측',
#      'priceRangeMin': 140000,
#      'priceRangeMax': 240000,
#      'openDate': '201709',
#      'openEra': '',
#      'businessHours': '',
#      'menu': '',
#      'dayOff': '',
#      'newOpenDate': '2017년 09월 '},
#     'juso': {'detailAddress': '',
#      'roadAddrPart1': '서울특별시 강남구 학동로55길 12-12',
#      'roadAddrPart2': '(청담동)',
#      'jibunAddr': '서울특별시 강남구 청담동 38-4',
#      'engAddr': '12-12, Hakdong-ro 55-gil, Gangnam-gu, Seoul',
#      'zipNo': '06065',
#      'admCd': '1168010400',
#      'detBdNmList': '',
#      'bdNm': '',
#      'siNm': '서울특별시',
#      'sggNm': '강남구',
#      'emdNm': '청담동',
#      'liNm': '',
#      'rn': '학동로55길',
#      'buldMnnm': '12',
#      'buldSlno': '12',
#      'zone2_1': '서울 강남',
#      'zone2_2': '청담동/강남구청역',
#      'map_1': '서울 강남지역',
#      'map_2': 'g. 학동사거리-강남구청역'},
#     'gps': {'latitude': 37.518997, 'longitude': 127.042238},
#     'review': {'review': '박무현 셰프의 컨템포러리한 프렌치 레스토랑. 계절에 따라 다른 테마로 준비되는 다양한 요리를 정교한 플레이팅으로 내어 준다. 탁 트인 오픈 키친과 모던한 인테리어가 돋보이며, 다이닝룸이 내려다보이는 프라이빗한 룸도 갖추고 있다.',
#      'reviewSimple': '박무현 셰프의 컨템포러리한 프렌치 레스토랑. 계절에 따라 다른 테마로 준비되는 다양한 요리를 정교한 플레이팅으로 내어 준다. 탁 트인 오픈 키친과 모던한 인테리어가 돋보이며, 다이닝룸이 내려다보이는 프라이빗한 룸도 갖추고 있다.',
#      'readerReview': '',
#      'businessReview': ''},
#     'extraInfo': {'wineInputType': 'NO_CHECK',
#      'wineInputYesEtc': '',
#      'wineCorkageEtc': '',
#      'holidayYn': True,
#      'wineOrderYn': False,
#      'holidayType': 'HOLIDAY_NOT',
#      'holidayEtc': '',
#      'timeEtc': ''},
#     'tags': '',
#     'etcInfo': {'interior': '',
#      'seat': '',
#      'room': '',
#      'toilet': None,
#      'toiletEtc': '',
#      'chain': False,
#      'close': False,
#      'renewal': False,
#      'reviewerRecommend': False,
#      'onlySiteView': False,
#      'head': '',
#      'branch': ''},
#     'status': 'ACTIVE',
#     'buzUsername': '',
#     'brandMatchStatus': 'NORMAL',
#     'brandRejectReason': '',
#     'orderDescending': 0,
#     'foodTypeDetails': None,
#     'features': None,
#     'countEvaluate': 0,
#     'bookmark': False,
#     'workingHour': '현재 브레이크 타임<br/>18:00부터 영업 시작',
#     'hourInfoBreakEnd2Times': None,
#     'foodTypes': ['컨템포러리', '프랑스식'],
#     'foodDetailTypes': ['컨템포러리', '프랑스식'],
#     'feature107': False,
#     'brandBranches': [],
#     'expiredBusinessDate': True,
#     'brandHead': None,
#     'firstImage': {'createdDate': 1754970495000,
#      'url': '/images/es_4ae5bbb4ec6a49f2a125169be75c5703.png',
#      'orderAscending': 0},
#     'firstLogoImage': None,
#     '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29243'},
#      'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29243{?projection}',
#       'templated': True},
#      'childrenRestaurants': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29243/childrenRestaurants{?projection}',
#       'templated': True},
#      'holidayList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29243/holidayList'},
#      'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29243/relativeWriter'},
#      'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29243/evaluates'},
#      'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29243/restaurantFeatures'},
#      'menuList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29243/menuList'},
#      'businessOrders': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29243/businessOrders'},
#      'wineList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29243/wineList'},
#      'hourList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29243/hourList'},
#      'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29243/reports'},
#      'parentRestaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29243/parentRestaurant{?projection}',
#       'templated': True},
#      'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29243/foodTypeCategories'}}},
#    {'createdDate': 1503281253000,
#     'id': 29206,
#     'headerInfo': {'nameKR': '고료리켄',
#      'nameEN': '',
#      'nameCN': '小料理健',
#      'bookYear': '2025',
#      'ribbonType': 'RIBBON_THREE',
#      'ribbonTypeByOrdinal': 0},
#     'defaultInfo': {'chefName': '김건',
#      'website': '',
#      'websiteInstagram': '',
#      'websiteFacebook': '',
#      'phone': '02-511-7809',
#      'websiteStore': '',
#      'websiteReserveNaver': '',
#      'websiteReserveCatch': '',
#      'websiteReserveOther': ''},
#     'statusInfo': {'storeType': 'NOT',
#      'parkingType': 'VALET',
#      'parking': '',
#      'creditCard': '',
#      'visit': '도산공원 정문 맞은편. 오페라갤러리 옆 골목',
#      'priceRangeMin': 250000,
#      'priceRangeMax': 250000,
#      'openDate': '201705',
#      'openEra': '',
#      'businessHours': '',
#      'menu': '',
#      'dayOff': '',
#      'newOpenDate': '2017년 05월 '},
#     'juso': {'detailAddress': '2층',
#      'roadAddrPart1': '서울특별시 강남구 언주로152길 15-3',
#      'roadAddrPart2': '(신사동)',
#      'jibunAddr': '서울특별시 강남구 신사동 631-28',
#      'engAddr': '15-3, Eonju-ro 152-gil, Gangnam-gu, Seoul',
#      'zipNo': '06021',
#      'admCd': '1168010700',
#      'detBdNmList': '',
#      'bdNm': '',
#      'siNm': '서울특별시',
#      'sggNm': '강남구',
#      'emdNm': '신사동',
#      'liNm': '',
#      'rn': '언주로174길',
#      'buldMnnm': '15',
#      'buldSlno': '3',
#      'zone2_1': '서울 강남',
#      'zone2_2': '압구정동/도산공원',
#      'map_1': '서울 강남지역',
#      'map_2': 'd. 언주로-도산공원-로데오거리'},
#     'gps': {'latitude': 37.52300901428518, 'longitude': 127.03480609700759},
#     'review': {'review': '김건 셰프가 내는 컨템포러리 재패니즈 퀴진. 신선한 제철 식재료를 사용해 만든 요리를 코스로 낸다. 일식에 프렌치 또는 이탈리안 터치가 가미된 스타일의 오마카세를 맛볼 수 있다.',
#      'reviewSimple': '김건 셰프가 내는 컨템포러리 재패니즈 퀴진. 신선한 제철 식재료를 사용해 만든 요리를 코스로 낸다. 일식에 프렌치 또는 이탈리안 터치가 가미된 스타일의 오마카세를 맛볼 수 있다.',
#      'readerReview': '',
#      'businessReview': ''},
#     'extraInfo': {'wineInputType': 'NO_CHECK',
#      'wineInputYesEtc': '',
#      'wineCorkageEtc': '',
#      'holidayYn': True,
#      'wineOrderYn': False,
#      'holidayType': 'HOLIDAY_NOT',
#      'holidayEtc': '',
#      'timeEtc': ''},
#     'tags': '',
#     'etcInfo': {'interior': '',
#      'seat': '',
#      'room': '',
#      'toilet': None,
#      'toiletEtc': '',
#      'chain': False,
#      'close': False,
#      'renewal': False,
#      'reviewerRecommend': False,
#      'onlySiteView': False,
#      'head': '',
#      'branch': ''},
#     'status': 'ACTIVE',
#     'buzUsername': '',
#     'brandMatchStatus': 'NORMAL',
#     'brandRejectReason': '',
#     'orderDescending': 0,
#     'foodTypeDetails': None,
#     'features': None,
#     'countEvaluate': 0,
#     'bookmark': False,
#     'workingHour': '영업 시작 전<br/>18:00부터 영업 시작',
#     'hourInfoBreakEnd2Times': None,
#     'foodTypes': ['일식', '모던재패니즈', '컨템포러리'],
#     'foodDetailTypes': ['모던재패니즈', '컨템포러리'],
#     'feature107': False,
#     'brandBranches': [],
#     'expiredBusinessDate': True,
#     'brandHead': None,
#     'firstImage': {'createdDate': 1754899532000,
#      'url': '/images/es_69118b854f9e4b7f828c41bfea5f4eaa.jpg',
#      'orderAscending': 0},
#     'firstLogoImage': None,
#     '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29206'},
#      'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29206{?projection}',
#       'templated': True},
#      'childrenRestaurants': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29206/childrenRestaurants{?projection}',
#       'templated': True},
#      'holidayList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29206/holidayList'},
#      'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29206/relativeWriter'},
#      'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29206/evaluates'},
#      'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29206/restaurantFeatures'},
#      'menuList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29206/menuList'},
#      'businessOrders': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29206/businessOrders'},
#      'wineList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29206/wineList'},
#      'hourList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29206/hourList'},
#      'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29206/reports'},
#      'parentRestaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29206/parentRestaurant{?projection}',
#       'templated': True},
#      'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29206/foodTypeCategories'}}},
#    {'createdDate': 1677136826000,
#     'id': 34659,
#     'headerInfo': {'nameKR': '팔레트',
#      'nameEN': 'palate',
#      'nameCN': '',
#      'bookYear': '2025',
#      'ribbonType': 'RIBBON_THREE',
#      'ribbonTypeByOrdinal': 0},
#     'defaultInfo': {'chefName': '김재훈 셰프, 박민욱 소믈리에',
#      'website': '',
#      'websiteInstagram': 'https://www.instagram.com/palate.busan/ ',
#      'websiteFacebook': '',
#      'phone': '051-626-2364  ',
#      'websiteStore': '',
#      'websiteReserveNaver': '',
#      'websiteReserveCatch': '',
#      'websiteReserveOther': ''},
#     'statusInfo': {'storeType': 'NOT',
#      'parkingType': 'YES',
#      'parking': '',
#      'creditCard': '',
#      'visit': '',
#      'priceRangeMin': 88000,
#      'priceRangeMax': 200000,
#      'openDate': '',
#      'openEra': '',
#      'businessHours': '12:00~15:00/18:00~22:00(마지막 주문 19:30) ',
#      'menu': '런치코스(8만8천원), 디너코스(20만원)',
#      'dayOff': '월, 화요일 휴무',
#      'newOpenDate': ''},
#     'juso': {'detailAddress': '메르씨엘 3층',
#      'roadAddrPart1': '부산광역시 해운대구 달맞이길65번길 154',
#      'roadAddrPart2': ' (중동)',
#      'jibunAddr': '부산광역시 해운대구 중동 1502-12 메르씨엘',
#      'engAddr': '154 Dalmaji-gil 65beon-gil, Haeundae-gu, Busan',
#      'zipNo': '48117',
#      'admCd': '2635010600',
#      'detBdNmList': '',
#      'bdNm': '메르씨엘',
#      'siNm': '부산광역시',
#      'sggNm': '해운대구',
#      'emdNm': '중동',
#      'liNm': '',
#      'rn': '',
#      'buldMnnm': '154',
#      'buldSlno': '0',
#      'zone2_1': '부산',
#      'zone2_2': '해운대구(해운대/달맞이길/송정)',
#      'map_1': '',
#      'map_2': ''},
#     'gps': {'latitude': 35.1565249148798, 'longitude': 129.178359990487},
#     'review': {'review': '프렌치 쿠킹 테크닉과 다양한 재료의 조합을 바탕으로 창의적인 요리를 하는 김재훈 셰프의 다이닝 레스토랑. 아뮈즈에서 시작해서 애피타이저, 메인 요리까지 고급 식재료를 사용한 아름답고 섬세한 플레이팅의 요리를 즐길 수 있다. 푸른 바다가 시원하게 펼쳐지는 달맞이고개의 전망도 좋다.',
#      'reviewSimple': '',
#      'readerReview': '',
#      'businessReview': ''},
#     'extraInfo': {'wineInputType': 'NO_CHECK',
#      'wineInputYesEtc': '',
#      'wineCorkageEtc': '',
#      'holidayYn': True,
#      'wineOrderYn': False,
#      'holidayType': 'HOLIDAY_NOT',
#      'holidayEtc': '',
#      'timeEtc': ''},
#     'tags': '',
#     'etcInfo': {'interior': '',
#      'seat': '',
#      'room': '',
#      'toilet': None,
#      'toiletEtc': '',
#      'chain': False,
#      'close': False,
#      'renewal': False,
#      'reviewerRecommend': False,
#      'onlySiteView': False,
#      'head': '',
#      'branch': ''},
#     'status': 'ACTIVE',
#     'buzUsername': '',
#     'brandMatchStatus': 'NORMAL',
#     'brandRejectReason': '',
#     'orderDescending': 3194,
#     'foodTypeDetails': None,
#     'features': None,
#     'countEvaluate': 0,
#     'bookmark': False,
#     'workingHour': '영업시간 정보 없음.',
#     'hourInfoBreakEnd2Times': None,
#     'foodTypes': ['컨템포러리'],
#     'foodDetailTypes': ['컨템포러리'],
#     'feature107': False,
#     'brandBranches': [],
#     'expiredBusinessDate': True,
#     'brandHead': None,
#     'firstImage': {'createdDate': 1754402599000,
#      'url': '/images/es_b059501d477d4df8a28d9fd6f73b0e4b.jpg',
#      'orderAscending': 0},
#     'firstLogoImage': None,
#     '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/34659'},
#      'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/34659{?projection}',
#       'templated': True},
#      'childrenRestaurants': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/34659/childrenRestaurants{?projection}',
#       'templated': True},
#      'holidayList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/34659/holidayList'},
#      'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/34659/relativeWriter'},
#      'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/34659/evaluates'},
#      'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/34659/restaurantFeatures'},
#      'menuList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/34659/menuList'},
#      'businessOrders': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/34659/businessOrders'},
#      'wineList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/34659/wineList'},
#      'hourList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/34659/hourList'},
#      'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/34659/reports'},
#      'parentRestaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/34659/parentRestaurant{?projection}',
#       'templated': True},
#      'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/34659/foodTypeCategories'}}},
#    {'createdDate': 1441600572000,
#     'id': 28236,
#     'headerInfo': {'nameKR': '본앤브레드',
#      'nameEN': 'BORN&BRED',
#      'nameCN': '',
#      'bookYear': '2025',
#      'ribbonType': 'RIBBON_THREE',
#      'ribbonTypeByOrdinal': 0},
#     'defaultInfo': {'chefName': '',
#      'website': 'http://www.bandb.co.kr/',
#      'websiteInstagram': 'https://www.instagram.com/bornandbredkorea',
#      'websiteFacebook': '',
#      'phone': '02-2294-5005',
#      'websiteStore': '',
#      'websiteReserveNaver': '',
#      'websiteReserveCatch': '',
#      'websiteReserveOther': ''},
#     'statusInfo': {'storeType': 'NOT',
#      'parkingType': 'VALET',
#      'parking': '',
#      'creditCard': 'y',
#      'visit': '',
#      'priceRangeMin': 100000,
#      'priceRangeMax': 380000,
#      'openDate': '20180320',
#      'openEra': '',
#      'businessHours': '',
#      'menu': '',
#      'dayOff': '',
#      'newOpenDate': '2018년 03월 20일'},
#     'juso': {'detailAddress': '',
#      'roadAddrPart1': '서울특별시 성동구 마장로42길 1',
#      'roadAddrPart2': '(마장동)',
#      'jibunAddr': '서울특별시 성동구 마장동 781-15 새림약국',
#      'engAddr': '1, Majang-ro 42-gil, Seongdong-gu, Seoul',
#      'zipNo': '04757',
#      'admCd': '1120010500',
#      'detBdNmList': '',
#      'bdNm': '새림약국',
#      'siNm': '서울특별시',
#      'sggNm': '성동구',
#      'emdNm': '마장동',
#      'liNm': '',
#      'rn': '마장로37길',
#      'buldMnnm': '1',
#      'buldSlno': '0',
#      'zone2_1': '서울 강북',
#      'zone2_2': '왕십리/마장동/장안동',
#      'map_1': '서울 강북지역',
#      'map_2': 'Y. 마장동-왕십리'},
#     'gps': {'latitude': 37.566790715500474, 'longitude': 127.04450198300889},
#     'review': {'review': '마장동 우시장 부근에 자리한 고급 부티크 정육점. 한우오마카세의 열풍을 일으킨 주역이다. 품질이 보장되는 소고기구이를 맛볼 수 있다. 1층과 2층은 캐주얼 다이닝으로 일반 고깃집처럼 운영되며, 3층에서는 프라이빗한 오마카세를 즐길 수 있다. 지하 1층은 소수 인원의 예약제로만 운영된다.',
#      'reviewSimple': '마장동 우시장 부근에 자리한 고급 부티크 정육점. 한우오마카세의 열풍을 일으킨 주역이다. 품질이 보장되는 소고기구이를 맛볼 수 있다. 1층과 2층은 캐주얼 다이닝으로 일반 고깃집처럼 운영되며, 3층에서는 프라이빗한 오마카세를 즐길 수 있다. 지하 1층은 소수 인원의 예약제로만 운영된다.',
#      'readerReview': '',
#      'businessReview': ''},
#     'extraInfo': {'wineInputType': 'NO_CHECK',
#      'wineInputYesEtc': '',
#      'wineCorkageEtc': '',
#      'holidayYn': True,
#      'wineOrderYn': False,
#      'holidayType': 'HOLIDAY_NOT',
#      'holidayEtc': '',
#      'timeEtc': ''},
#     'tags': '핫플맛집',
#     'etcInfo': {'interior': '',
#      'seat': '',
#      'room': '',
#      'toilet': None,
#      'toiletEtc': '',
#      'chain': False,
#      'close': False,
#      'renewal': False,
#      'reviewerRecommend': False,
#      'onlySiteView': False,
#      'head': '',
#      'branch': ''},
#     'status': 'ACTIVE',
#     'buzUsername': '',
#     'brandMatchStatus': 'NORMAL',
#     'brandRejectReason': '',
#     'orderDescending': 0,
#     'foodTypeDetails': None,
#     'features': None,
#     'countEvaluate': 0,
#     'bookmark': False,
#     'workingHour': '오늘 휴무일',
#     'hourInfoBreakEnd2Times': None,
#     'foodTypes': ['한식(육류)', '한우오마카세', '소고기구이'],
#     'foodDetailTypes': ['한우오마카세', '소고기구이'],
#     'feature107': True,
#     'brandBranches': [],
#     'expiredBusinessDate': True,
#     'brandHead': None,
#     'firstImage': {'createdDate': 1754364886000,
#      'url': '/images/es_3082de767ba7485180fedba7392db62f.jpg',
#      'orderAscending': 0},
#     'firstLogoImage': None,
#     '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28236'},
#      'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28236{?projection}',
#       'templated': True},
#      'childrenRestaurants': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28236/childrenRestaurants{?projection}',
#       'templated': True},
#      'holidayList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28236/holidayList'},
#      'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28236/relativeWriter'},
#      'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28236/evaluates'},
#      'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28236/restaurantFeatures'},
#      'menuList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28236/menuList'},
#      'businessOrders': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28236/businessOrders'},
#      'wineList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28236/wineList'},
#      'hourList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28236/hourList'},
#      'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28236/reports'},
#      'parentRestaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28236/parentRestaurant{?projection}',
#       'templated': True},
#      'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28236/foodTypeCategories'}}},
#    {'createdDate': 1436236247000,
#     'id': 28167,
#     'headerInfo': {'nameKR': '권숙수',
#      'nameEN': 'KOREAN DINING KWONSOOKSOO',
#      'nameCN': '',
#      'bookYear': '2025',
#      'ribbonType': 'RIBBON_THREE',
#      'ribbonTypeByOrdinal': 0},
#     'defaultInfo': {'chefName': '권우중',
#      'website': 'http://kwonsooksoo.com',
#      'websiteInstagram': 'https://www.instagram.com/kwonsooksoo/',
#      'websiteFacebook': '',
#      'phone': '0507-1354-6268',
#      'websiteStore': '',
#      'websiteReserveNaver': '',
#      'websiteReserveCatch': '',
#      'websiteReserveOther': ''},
#     'statusInfo': {'storeType': 'NOT',
#      'parkingType': 'VALET',
#      'parking': '',
#      'creditCard': 'y',
#      'visit': '청담사거리에서 학동사거리 방향으로 직진. 순수도산점에서 우회전하면 우측',
#      'priceRangeMin': 210000,
#      'priceRangeMax': 340000,
#      'openDate': '20150701',
#      'openEra': '',
#      'businessHours': '',
#      'menu': '',
#      'dayOff': '',
#      'newOpenDate': '2015년 07월 01일'},
#     'juso': {'detailAddress': '이에스빌딩 4층',
#      'roadAddrPart1': '서울특별시 강남구 압구정로80길 37',
#      'roadAddrPart2': '(청담동)',
#      'jibunAddr': '서울특별시 강남구 청담동 92-18 이에스빌딩',
#      'engAddr': '37, Apgujeong-ro 80-gil, Gangnam-gu, Seoul',
#      'zipNo': '06016',
#      'admCd': '1168010400',
#      'detBdNmList': '',
#      'bdNm': '이에스빌딩',
#      'siNm': '서울특별시',
#      'sggNm': '강남구',
#      'emdNm': '청담동',
#      'liNm': '',
#      'rn': '압구정로80길',
#      'buldMnnm': '37',
#      'buldSlno': '0',
#      'zone2_1': '서울 강남',
#      'zone2_2': '청담동/강남구청역',
#      'map_1': '서울 강남지역',
#      'map_2': ''},
#     'gps': {'latitude': 37.524328, 'longitude': 127.043571},
#     'review': {'review': '한식을 양식의 형식으로 풀어낸 모던한식 스타일을 선보이는 권우중 셰프의 한식당. 직접 담근 장과 김치, 식초를 사용하여 모던하면서도 한식 전통의 맛을 잘 살리고 있다는 평을 받고 있다. 전통적인 1인 독상을 구현한 점도 독특하다. 여러 종류의 김치로 구성된 김치 카트를 선보이는 등 끊임없이 새로운 모습을 보여준다.',
#      'reviewSimple': '한식을 양식의 형식으로 풀어낸 모던한식 스타일을 선보이는 권우중 셰프의 한식당. 직접 담근 장과 김치, 식초를 사용하여 모던하면서도 한식 전통의 맛을 잘 살리고 있다는 평을 받고 있다. 전통적인 1인 독상을 구현한 점도 독특하다. 여러 종류의 김치로 구성된 김치 카트를 선보이는 등 끊임없이 새로운 모습을 보여준다.',
#      'readerReview': '',
#      'businessReview': ''},
#     'extraInfo': {'wineInputType': 'NO_CHECK',
#      'wineInputYesEtc': '',
#      'wineCorkageEtc': '',
#      'holidayYn': True,
#      'wineOrderYn': False,
#      'holidayType': 'FESTIVAL',
#      'holidayEtc': '',
#      'timeEtc': ''},
#     'tags': '',
#     'etcInfo': {'interior': '',
#      'seat': '',
#      'room': '',
#      'toilet': None,
#      'toiletEtc': '',
#      'chain': False,
#      'close': False,
#      'renewal': False,
#      'reviewerRecommend': False,
#      'onlySiteView': False,
#      'head': '',
#      'branch': ''},
#     'status': 'ACTIVE',
#     'buzUsername': '',
#     'brandMatchStatus': 'NORMAL',
#     'brandRejectReason': '',
#     'orderDescending': 0,
#     'foodTypeDetails': None,
#     'features': None,
#     'countEvaluate': 0,
#     'bookmark': False,
#     'workingHour': '현재 브레이크 타임<br/>18:00부터 영업 시작',
#     'hourInfoBreakEnd2Times': None,
#     'foodTypes': ['한식(일반한식)', '모던한식'],
#     'foodDetailTypes': ['모던한식'],
#     'feature107': False,
#     'brandBranches': [],
#     'expiredBusinessDate': True,
#     'brandHead': None,
#     'firstImage': {'createdDate': 1754294415000,
#      'url': '/images/es_c03a2e8289d44d18ae79e5b85cce5ed3.jpg',
#      'orderAscending': 0},
#     'firstLogoImage': None,
#     '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28167'},
#      'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28167{?projection}',
#       'templated': True},
#      'childrenRestaurants': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28167/childrenRestaurants{?projection}',
#       'templated': True},
#      'holidayList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28167/holidayList'},
#      'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28167/relativeWriter'},
#      'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28167/evaluates'},
#      'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28167/restaurantFeatures'},
#      'menuList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28167/menuList'},
#      'businessOrders': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28167/businessOrders'},
#      'wineList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28167/wineList'},
#      'hourList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28167/hourList'},
#      'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28167/reports'},
#      'parentRestaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28167/parentRestaurant{?projection}',
#       'templated': True},
#      'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28167/foodTypeCategories'}}},
#    {'createdDate': 1399598620000,
#     'id': 27144,
#     'headerInfo': {'nameKR': '밍글스',
#      'nameEN': 'Mingles',
#      'nameCN': '',
#      'bookYear': '2025',
#      'ribbonType': 'RIBBON_THREE',
#      'ribbonTypeByOrdinal': 0},
#     'defaultInfo': {'chefName': '강민구',
#      'website': 'http://www.restaurant-mingles.com',
#      'websiteInstagram': 'https://www.instagram.com/mingles_restaurant/',
#      'websiteFacebook': '',
#      'phone': '02-515-7306',
#      'websiteStore': '',
#      'websiteReserveNaver': '',
#      'websiteReserveCatch': '',
#      'websiteReserveOther': ''},
#     'statusInfo': {'storeType': 'NOT',
#      'parkingType': 'VALET',
#      'parking': '',
#      'creditCard': 'y',
#      'visit': '학동사거리에서 압구정로데오역 방향으로 직진. 버거킹에서 우회전 후 커피빈에서 좌회전',
#      'priceRangeMin': 300000,
#      'priceRangeMax': 400000,
#      'openDate': '20140505',
#      'openEra': '',
#      'businessHours': '',
#      'menu': '',
#      'dayOff': '',
#      'newOpenDate': '2014년 05월 05일'},
#     'juso': {'detailAddress': '힐탑빌딩 2층',
#      'roadAddrPart1': '서울특별시 강남구 도산대로67길 19',
#      'roadAddrPart2': '(청담동)',
#      'jibunAddr': '서울특별시 강남구 청담동 94-6',
#      'engAddr': '19, Dosan-daero 67-gil, Gangnam-gu, Seoul',
#      'zipNo': '06016',
#      'admCd': '1168010400',
#      'detBdNmList': '',
#      'bdNm': '',
#      'siNm': '서울특별시',
#      'sggNm': '강남구',
#      'emdNm': '청담동',
#      'liNm': '',
#      'rn': '선릉로',
#      'buldMnnm': '19',
#      'buldSlno': '0',
#      'zone2_1': '서울 강남',
#      'zone2_2': '청담동/강남구청역',
#      'map_1': '서울 강남지역',
#      'map_2': ''},
#     'gps': {'latitude': 37.52537011726149, 'longitude': 127.04416060872083},
#     'review': {'review': '국내외에서 이름을 드높이고 있는 강민구 셰프의 뉴코리안 레스토랑. 사찰음식과 한식 장인에게 전수받은 전통 한식 기법을 현대적으로 재해석한 한식을 맛볼 수 있다. 완벽을 지향하는 육수 내기 등 기본기를 중요시하고 있다. 실내 분위기도 모던하고 쾌적하며 서비스도 나무랄 데 없다. 2020년에 홍콩에 오픈한 한식당 한식구가 큰 인기를 끄는 등 글로벌 셰프로서의 위엄을 보여준다.',
#      'reviewSimple': '',
#      'readerReview': '',
#      'businessReview': ''},
#     'extraInfo': {'wineInputType': 'NO_CHECK',
#      'wineInputYesEtc': '',
#      'wineCorkageEtc': '',
#      'holidayYn': True,
#      'wineOrderYn': False,
#      'holidayType': 'HOLIDAY_NOT',
#      'holidayEtc': '',
#      'timeEtc': ''},
#     'tags': '',
#     'etcInfo': {'interior': '',
#      'seat': '',
#      'room': '',
#      'toilet': None,
#      'toiletEtc': '',
#      'chain': False,
#      'close': False,
#      'renewal': False,
#      'reviewerRecommend': False,
#      'onlySiteView': False,
#      'head': '',
#      'branch': ''},
#     'status': 'ACTIVE',
#     'buzUsername': '',
#     'brandMatchStatus': 'NORMAL',
#     'brandRejectReason': '',
#     'orderDescending': 0,
#     'foodTypeDetails': None,
#     'features': None,
#     'countEvaluate': 0,
#     'bookmark': False,
#     'workingHour': '현재 영업중<br/>22:00에 영업 종료',
#     'hourInfoBreakEnd2Times': None,
#     'foodTypes': ['한식(일반한식)', '뉴코리안'],
#     'foodDetailTypes': ['뉴코리안'],
#     'feature107': False,
#     'brandBranches': [],
#     'expiredBusinessDate': True,
#     'brandHead': None,
#     'firstImage': {'createdDate': 1754197041000,
#      'url': '/images/es_864204db95a147c991ec971272b3efc4.jpg',
#      'orderAscending': 0},
#     'firstLogoImage': {'createdDate': 1754197041000,
#      'url': '/images/es_53a3cc2ac45b4ea083f688a8f5af274a.png',
#      'orderAscending': 0},
#     '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/27144'},
#      'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/27144{?projection}',
#       'templated': True},
#      'childrenRestaurants': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/27144/childrenRestaurants{?projection}',
#       'templated': True},
#      'holidayList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/27144/holidayList'},
#      'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/27144/relativeWriter'},
#      'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/27144/evaluates'},
#      'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/27144/restaurantFeatures'},
#      'menuList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/27144/menuList'},
#      'businessOrders': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/27144/businessOrders'},
#      'wineList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/27144/wineList'},
#      'hourList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/27144/hourList'},
#      'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/27144/reports'},
#      'parentRestaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/27144/parentRestaurant{?projection}',
#       'templated': True},
#      'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/27144/foodTypeCategories'}}},
#    {'createdDate': 1646042409000,
#     'id': 32608,
#     'headerInfo': {'nameKR': '솔밤',
#      'nameEN': 'SOLBAM',
#      'nameCN': '',
#      'bookYear': '2025',
#      'ribbonType': 'RIBBON_THREE',
#      'ribbonTypeByOrdinal': 0},
#     'defaultInfo': {'chefName': '엄태준 셰프',
#      'website': 'https://www.restaurantsolbam.com/',
#      'websiteInstagram': 'https://www.instagram.com/solbam_restaurant/',
#      'websiteFacebook': '',
#      'phone': '070-4405-7788',
#      'websiteStore': '',
#      'websiteReserveNaver': '',
#      'websiteReserveCatch': '',
#      'websiteReserveOther': ''},
#     'statusInfo': {'storeType': 'NOT',
#      'parkingType': 'YES',
#      'parking': '',
#      'creditCard': 'y',
#      'visit': '',
#      'priceRangeMin': 350000,
#      'priceRangeMax': 400000,
#      'openDate': '20210923',
#      'openEra': '',
#      'businessHours': '17:30~22:30 \r\n',
#      'menu': '솔밤코스(35만원), 베버리지페어링(25만원)\r\n',
#      'dayOff': '일요일 휴무',
#      'newOpenDate': '2021년 09월 23일'},
#     'juso': {'detailAddress': ' 논현백영센터 2층',
#      'roadAddrPart1': '서울특별시 강남구 학동로 231',
#      'roadAddrPart2': ' (논현동)',
#      'jibunAddr': '서울특별시 강남구 논현동 89-10',
#      'engAddr': '231 Hakdong-ro, Gangnam-gu, Seoul',
#      'zipNo': '06053',
#      'admCd': '1168010800',
#      'detBdNmList': '',
#      'bdNm': '',
#      'siNm': '서울특별시',
#      'sggNm': '강남구',
#      'emdNm': '논현동',
#      'liNm': '',
#      'rn': '',
#      'buldMnnm': '231',
#      'buldSlno': '0',
#      'zone2_1': '서울 강남',
#      'zone2_2': '청담동/강남구청역',
#      'map_1': '서울 강남지역',
#      'map_2': 'g. 학동사거리-강남구청역'},
#     'gps': {'latitude': 37.5154927557092, 'longitude': 127.0341900991},
#     'review': {'review': '한식을 기반으로한 컨템포러리 파인 다이닝. 뉴욕 일레븐매디슨파크, 서울 임프레션 등을 거친 엄태준 셰프가 독창적이고 섬세한 코스로 풀어낸다. 고동연 소믈리에의 독창적인 와인 페어링과 함께 12코스가 조화롭게 진행된다. 솔밤은 엄셰프가 유년을 보낸 안동의 지명이다.',
#      'reviewSimple': '',
#      'readerReview': '',
#      'businessReview': ''},
#     'extraInfo': {'wineInputType': 'YES',
#      'wineInputYesEtc': '750ml 와인 한 병',
#      'wineCorkageEtc': '1병당 150000원',
#      'holidayYn': True,
#      'wineOrderYn': False,
#      'holidayType': 'HOLIDAY_NOT',
#      'holidayEtc': '',
#      'timeEtc': ''},
#     'tags': '',
#     'etcInfo': {'interior': '',
#      'seat': '',
#      'room': '',
#      'toilet': None,
#      'toiletEtc': '',
#      'chain': False,
#      'close': False,
#      'renewal': False,
#      'reviewerRecommend': False,
#      'onlySiteView': False,
#      'head': '',
#      'branch': ''},
#     'status': 'ACTIVE',
#     'buzUsername': '',
#     'brandMatchStatus': 'NORMAL',
#     'brandRejectReason': '',
#     'orderDescending': 2461,
#     'foodTypeDetails': None,
#     'features': None,
#     'countEvaluate': 0,
#     'bookmark': False,
#     'workingHour': '영업 시작 전<br/>17:30부터 영업 시작',
#     'hourInfoBreakEnd2Times': None,
#     'foodTypes': ['한식(일반한식)', '뉴코리안'],
#     'foodDetailTypes': ['뉴코리안'],
#     'feature107': False,
#     'brandBranches': [],
#     'expiredBusinessDate': True,
#     'brandHead': None,
#     'firstImage': {'createdDate': 1754112580000,
#      'url': '/images/es_319e1ace47a54479b9dd13897d232594.jpg',
#      'orderAscending': 0},
#     'firstLogoImage': None,
#     '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/32608'},
#      'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/32608{?projection}',
#       'templated': True},
#      'childrenRestaurants': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/32608/childrenRestaurants{?projection}',
#       'templated': True},
#      'holidayList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/32608/holidayList'},
#      'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/32608/relativeWriter'},
#      'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/32608/evaluates'},
#      'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/32608/restaurantFeatures'},
#      'menuList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/32608/menuList'},
#      'businessOrders': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/32608/businessOrders'},
#      'wineList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/32608/wineList'},
#      'hourList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/32608/hourList'},
#      'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/32608/reports'},
#      'parentRestaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/32608/parentRestaurant{?projection}',
#       'templated': True},
#      'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/32608/foodTypeCategories'}}},
#    {'createdDate': 1531327909000,
#     'id': 29427,
#     'headerInfo': {'nameKR': '미토우',
#      'nameEN': '',
#      'nameCN': '未到',
#      'bookYear': '2025',
#      'ribbonType': 'RIBBON_THREE',
#      'ribbonTypeByOrdinal': 0},
#     'defaultInfo': {'chefName': '김보미, 권영운',
#      'website': '',
#      'websiteInstagram': 'https://www.instagram.com/mitouseoul',
#      'websiteFacebook': '',
#      'phone': '0507-1306-9914',
#      'websiteStore': '',
#      'websiteReserveNaver': '',
#      'websiteReserveCatch': '',
#      'websiteReserveOther': ''},
#     'statusInfo': {'storeType': 'NOT',
#      'parkingType': 'VALET',
#      'parking': '',
#      'creditCard': 'y',
#      'visit': '',
#      'priceRangeMin': 280000,
#      'priceRangeMax': 300000,
#      'openDate': '201802',
#      'openEra': '',
#      'businessHours': '',
#      'menu': '',
#      'dayOff': '',
#      'newOpenDate': '2018년 02월 '},
#     'juso': {'detailAddress': '',
#      'roadAddrPart1': '서울특별시 강남구 도산대로70길 24',
#      'roadAddrPart2': '(청담동)',
#      'jibunAddr': '서울특별시 강남구 청담동 17-24',
#      'engAddr': '24 Dosan-daero 70-gil, Gangnam-gu, Seoul',
#      'zipNo': '06064',
#      'admCd': '1168010400',
#      'detBdNmList': '',
#      'bdNm': '',
#      'siNm': '서울특별시',
#      'sggNm': '강남구',
#      'emdNm': '청담동',
#      'liNm': '',
#      'rn': '논현로151길',
#      'buldMnnm': '24',
#      'buldSlno': '0',
#      'zone2_1': '서울 강남',
#      'zone2_2': '청담동/강남구청역',
#      'map_1': '서울 강남지역',
#      'map_2': 'g. 학동사거리-강남구청역'},
#     'gps': {'latitude': 37.5221099525237, 'longitude': 127.045055412969},
#     'review': {'review': '일본에서 수련 후 귀국한 권영운, 김보미 오너셰프의 일본요리 전문점. 담담하면서도 화사한 일본요리의 특징을 잘 살리면서도 조금씩 한국적인 느낌을 가미한 완성도 높은 요리를 선보인다. 일본과는 다른 국내 식재료 상황을 극복하기 위해 직접 채소나 쌀을 재배하거나 토종닭을 기르고 미소를 담그는 등 갖은 노력을 아끼지 않으며 많은 미식가들과 매체로부터 높은 평가를 받고 있다.',
#      'reviewSimple': '',
#      'readerReview': '',
#      'businessReview': ''},
#     'extraInfo': {'wineInputType': 'YES',
#      'wineInputYesEtc': '',
#      'wineCorkageEtc': '',
#      'holidayYn': True,
#      'wineOrderYn': False,
#      'holidayType': 'HOLIDAY_NOT',
#      'holidayEtc': '',
#      'timeEtc': ''},
#     'tags': '',
#     'etcInfo': {'interior': '',
#      'seat': '',
#      'room': '',
#      'toilet': None,
#      'toiletEtc': '',
#      'chain': False,
#      'close': False,
#      'renewal': False,
#      'reviewerRecommend': False,
#      'onlySiteView': False,
#      'head': '',
#      'branch': ''},
# ...
#      'wineList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31431/wineList'},
#      'hourList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31431/hourList'},
#      'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31431/reports'},
#      'parentRestaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31431/parentRestaurant{?projection}',
#       'templated': True},
#      'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31431/foodTypeCategories'}}},
#    {'createdDate': 1605755895000,
#     'id': 31432,
#     'headerInfo': {'nameKR': '코자차',
#      'nameEN': 'Kojacha',
#      'nameCN': '',
#      'bookYear': '2025',
#      'ribbonType': 'RIBBON_THREE',
#      'ribbonTypeByOrdinal': 0},
#     'defaultInfo': {'chefName': '최유강',
#      'website': '',
#      'websiteInstagram': 'https://www.instagram.com/kojacha.official/',
#      'websiteFacebook': '',
#      'phone': '010-9023-7772',
#      'websiteStore': '',
#      'websiteReserveNaver': '',
#      'websiteReserveCatch': '',
#      'websiteReserveOther': ''},
#     'statusInfo': {'storeType': 'NOT',
#      'parkingType': 'YES',
#      'parking': '',
#      'creditCard': 'y',
#      'visit': '',
#      'priceRangeMin': 150000,
#      'priceRangeMax': 250000,
#      'openDate': '202003',
#      'openEra': '',
#      'businessHours': '',
#      'menu': '',
#      'dayOff': '',
#      'newOpenDate': '2020년 03월 '},
#     'juso': {'detailAddress': '',
#      'roadAddrPart1': '서울특별시 강남구 학동로97길 17',
#      'roadAddrPart2': '(청담동)',
#      'jibunAddr': '서울특별시 강남구 청담동 70-6',
#      'engAddr': '17, Hakdong-ro 97-gil, Gangnam-gu, Seoul',
#      'zipNo': '06072',
#      'admCd': '1168010400',
#      'detBdNmList': '',
#      'bdNm': '',
#      'siNm': '서울특별시',
#      'sggNm': '강남구',
#      'emdNm': '청담동',
#      'liNm': '',
#      'rn': '',
#      'buldMnnm': '17',
#      'buldSlno': '0',
#      'zone2_1': '서울 강남',
#      'zone2_2': '청담동/강남구청역',
#      'map_1': '서울 강남지역',
#      'map_2': 'f. 청담사거리-영동대교남단-청담역'},
#     'gps': {'latitude': 37.5208683828468, 'longitude': 127.055215316615},
#     'review': {'review': '한식, 일식, 중식의 앞글자를 따서 만든 레스토랑. 신라 호텔에서 20년 가까이 경력을 쌓은 두 셰프의 노하우가 담긴 세심한 코스요리를 선보인다. ',
#      'reviewSimple': '한식, 일식, 중식의 앞글자를 따서 만든 레스토랑. 신라 호텔에서 20년 가까이 경력을 쌓은 두 셰프의 노하우가 담긴 세심한 코스요리를 선보인다. ',
#      'readerReview': '',
#      'businessReview': ''},
#     'extraInfo': {'wineInputType': 'NO_CHECK',
#      'wineInputYesEtc': '',
#      'wineCorkageEtc': '',
#      'holidayYn': True,
#      'wineOrderYn': False,
#      'holidayType': 'HOLIDAY_NOT',
#      'holidayEtc': '',
#      'timeEtc': ''},
#     'tags': '',
#     'etcInfo': {'interior': '',
#      'seat': '',
#      'room': '',
#      'toilet': None,
#      'toiletEtc': '',
#      'chain': False,
#      'close': False,
#      'renewal': False,
#      'reviewerRecommend': False,
#      'onlySiteView': False,
#      'head': '',
#      'branch': ''},
#     'status': 'ACTIVE',
#     'buzUsername': '',
#     'brandMatchStatus': 'NORMAL',
#     'brandRejectReason': '',
#     'orderDescending': 1689,
#     'foodTypeDetails': None,
#     'features': None,
#     'countEvaluate': 0,
#     'bookmark': False,
#     'workingHour': '현재 브레이크 타임<br/>18:00부터 영업 시작',
#     'hourInfoBreakEnd2Times': None,
#     'foodTypes': ['컨템포러리', '이노베이티브퀴진', '일식', '중식', '모던차이니즈'],
#     'foodDetailTypes': ['이노베이티브퀴진', '일식', '모던차이니즈'],
#     'feature107': True,
#     'brandBranches': [],
#     'expiredBusinessDate': True,
#     'brandHead': None,
#     'firstImage': {'createdDate': 1752642816000,
#      'url': '/images/es_c539db8e53104616a9fb381fa995179d.jpg',
#      'orderAscending': 0},
#     'firstLogoImage': None,
#     '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31432'},
#      'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31432{?projection}',
#       'templated': True},
#      'childrenRestaurants': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31432/childrenRestaurants{?projection}',
#       'templated': True},
#      'holidayList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31432/holidayList'},
#      'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31432/relativeWriter'},
#      'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31432/evaluates'},
#      'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31432/restaurantFeatures'},
#      'menuList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31432/menuList'},
#      'businessOrders': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31432/businessOrders'},
#      'wineList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31432/wineList'},
#      'hourList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31432/hourList'},
#      'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31432/reports'},
#      'parentRestaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31432/parentRestaurant{?projection}',
#       'templated': True},
#      'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31432/foodTypeCategories'}}},
#    {'createdDate': 1169743920000,
#     'id': 1534,
#     'headerInfo': {'nameKR': '낙원',
#      'nameEN': '',
#      'nameCN': '樂源',
#      'bookYear': '2025',
#      'ribbonType': 'RIBBON_THREE',
#      'ribbonTypeByOrdinal': 0},
#     'defaultInfo': {'chefName': '',
#      'website': 'https://mayfield.co.kr/dining/nakwon.html',
#      'websiteInstagram': 'https://www.instagram.com/mayfield_hotel/',
#      'websiteFacebook': 'https://www.facebook.com/mayfieldhotel',
#      'phone': '02-2660-9010',
#      'websiteStore': '',
#      'websiteReserveNaver': '',
#      'websiteReserveCatch': '',
#      'websiteReserveOther': ''},
#     'statusInfo': {'storeType': 'NOT',
#      'parkingType': 'YES',
#      'parking': '',
#      'creditCard': 'y',
#      'visit': '메이필드호텔 1층',
#      'priceRangeMin': 50000,
#      'priceRangeMax': 150000,
#      'openDate': '1983',
#      'openEra': '',
#      'businessHours': '11:30~14:30(마지막 주문 13:30)/17:30~ 21:30(마지막 주문 20:30) ',
#      'menu': '특생대대갈비, 특양념대갈비(각 270g 15만원), 한우꽃등심(130g 9만5천원), 한우등심불고기(200g 5만5천원), 한우양념갈비구이정식(200g 11만원), 낙지볶음(5만원), 해물파전(3만5천원)',
#      'dayOff': '연중무휴',
#      'newOpenDate': '1983년 '},
#     'juso': {'detailAddress': '메이필드호텔 1층',
#      'roadAddrPart1': '서울특별시 강서구 방화대로 94',
#      'roadAddrPart2': '(외발산동)',
#      'jibunAddr': '서울특별시 강서구 외발산동 426 메이필드호텔',
#      'engAddr': '94, Banghwa-daero, Gangseo-gu, Seoul',
#      'zipNo': '07506',
#      'admCd': '1150010700',
#      'detBdNmList': '기숙사,메이필드호텔,메이필드호텔 동관,사무실,스포츠동,신관,연회장,한식당,한정식당',
#      'bdNm': '메이필드호텔',
#      'siNm': '서울특별시',
#      'sggNm': '강서구',
#      'emdNm': '외발산동',
#      'liNm': '',
#      'rn': '방화대로',
#      'buldMnnm': '94',
#      'buldSlno': '0',
#      'zone2_1': '서울 강남',
#      'zone2_2': '김포/마곡',
#      'map_1': '서울 강남지역',
#      'map_2': 'x. 강서구-마곡'},
#     'gps': {'latitude': 37.54683, 'longitude': 126.8186},
#     'review': {'review': '갈비를 비롯한 한우구이를 전문으로 하고 있으며 가격대가 높은 만큼 품격 있는 분위기와 서비스를 즐길 수 있다. 재료 본연의 맛을 살린 음식의 맛이 좋다. 룸이 여러 개 있어 비즈니스 미팅에도 좋다. 낙원 안쪽에는 한정식집 봉래헌이 있다.',
#      'reviewSimple': '갈비를 비롯한 한우구이를 전문으로 하고 있으며 가격대가 높은 만큼 품격 있는 분위기와 서비스를 즐길 수 있다. 재료 본연의 맛을 살린 음식의 맛이 좋다. 룸이 여러 개 있어 비즈니스 미팅에도 좋다. 낙원 안쪽에는 한정식집 봉래헌이 있다.',
#      'readerReview': '',
#      'businessReview': ''},
#     'extraInfo': {'wineInputType': 'NO_CHECK',
#      'wineInputYesEtc': '',
#      'wineCorkageEtc': '',
#      'holidayYn': False,
#      'wineOrderYn': False,
#      'holidayType': 'HOLIDAY_NOT',
#      'holidayEtc': '',
#      'timeEtc': ''},
#     'tags': '한옥맛집',
#     'etcInfo': {'interior': '전통 한국식',
#      'seat': '',
#      'room': '',
#      'toilet': None,
#      'toiletEtc': '',
#      'chain': False,
#      'close': False,
#      'renewal': False,
#      'reviewerRecommend': False,
#      'onlySiteView': False,
#      'head': '',
#      'branch': ''},
#     'status': 'ACTIVE',
#     'buzUsername': '',
#     'brandMatchStatus': 'NORMAL',
#     'brandRejectReason': '',
#     'orderDescending': 0,
#     'foodTypeDetails': None,
#     'features': None,
#     'countEvaluate': 0,
#     'bookmark': False,
#     'workingHour': '현재 브레이크 타임<br/>17:30부터 영업 시작',
#     'hourInfoBreakEnd2Times': None,
#     'foodTypes': ['한식(육류)', '소갈비', '소고기구이'],
#     'foodDetailTypes': ['소갈비', '소고기구이'],
#     'feature107': True,
#     'brandBranches': [],
#     'expiredBusinessDate': True,
#     'brandHead': None,
#     'firstImage': {'createdDate': 1752564697000,
#      'url': '/images/1534_thumb.jpg',
#      'orderAscending': 0},
#     'firstLogoImage': None,
#     '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/1534'},
#      'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/1534{?projection}',
#       'templated': True},
#      'childrenRestaurants': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/1534/childrenRestaurants{?projection}',
#       'templated': True},
#      'holidayList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/1534/holidayList'},
#      'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/1534/relativeWriter'},
#      'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/1534/evaluates'},
#      'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/1534/restaurantFeatures'},
#      'menuList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/1534/menuList'},
#      'businessOrders': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/1534/businessOrders'},
#      'wineList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/1534/wineList'},
#      'hourList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/1534/hourList'},
#      'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/1534/reports'},
#      'parentRestaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/1534/parentRestaurant{?projection}',
#       'templated': True},
#      'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/1534/foodTypeCategories'}}},
#    {'createdDate': 1539581717000,
#     'id': 29567,
#     'headerInfo': {'nameKR': '라망시크레',
#      'nameEN': "L'Amant Secret",
#      'nameCN': '',
#      'bookYear': '2025',
#      'ribbonType': 'RIBBON_THREE',
#      'ribbonTypeByOrdinal': 0},
#     'defaultInfo': {'chefName': '손종원',
#      'website': '',
#      'websiteInstagram': 'https://www.instagram.com/lamant_secret/',
#      'websiteFacebook': '',
#      'phone': '02-317-4003 ',
#      'websiteStore': '',
#      'websiteReserveNaver': '',
#      'websiteReserveCatch': '',
#      'websiteReserveOther': ''},
#     'statusInfo': {'storeType': 'NOT',
#      'parkingType': 'YES',
#      'parking': '',
#      'creditCard': 'y',
#      'visit': '회현역 6번 출구 앞. 레스케이프 호텔 26층',
#      'priceRangeMin': 140000,
#      'priceRangeMax': 220000,
#      'openDate': '20180719',
#      'openEra': '',
#      'businessHours': '12:00~15:00(마지막 주문 13:30)/18:00~22:00(마지막 주문 19:30) ',
#      'menu': '런치셰프테이스팅코스(14만원), 런치와인페어링(12만원), 디너셰프테이스팅코스(22만원), 디너와인페어링(20만원)',
#      'dayOff': '일요일 휴무',
#      'newOpenDate': '2018년 07월 19일'},
#     'juso': {'detailAddress': '레스케이프 호텔 26층',
#      'roadAddrPart1': '서울특별시 중구 퇴계로 67',
#      'roadAddrPart2': '(회현동1가)',
#      'jibunAddr': '서울특별시 중구 회현동1가 194-19',
#      'engAddr': '67, Toegye-ro, Jung-gu, Seoul',
#      'zipNo': '04529',
#      'admCd': '1114012100',
#      'detBdNmList': '',
#      'bdNm': '',
#      'siNm': '서울특별시',
#      'sggNm': '중구',
#      'emdNm': '회현동1가',
#      'liNm': '',
#      'rn': '',
#      'buldMnnm': '67',
#      'buldSlno': '0',
#      'zone2_1': '서울 강북',
#      'zone2_2': '남대문/서울역/후암동',
#      'map_1': '서울 강북지역',
#      'map_2': 'R. 서울역-남산-남대문시장'},
#     'gps': {'latitude': 37.559733515077966, 'longitude': 126.97952350317435},
#     'review': {'review': '부티크호텔 레스케이프 호텔 최상층에 자리한 컨템포러리 프렌치 레스토랑. 세련된 플레이팅의 요리를 파리에 있는 듯한 분위기에서 즐길 수 있다. 코스 구성은 계절별로 바뀐다. 요리와 어울리는 내추럴 와인을 페어링해 즐길 수도 있다. 손종원 셰프가 이타닉가든과 라망시크레 모두 책임지고 있다.',
#      'reviewSimple': '부티크호텔 레스케이프 호텔 최상층에 자리한 컨템포러리 프렌치 레스토랑. 세련된 플레이팅의 요리를 파리에 있는 듯한 분위기에서 즐길 수 있다. 코스 구성은 계절별로 바뀐다. 요리와 어울리는 내추럴 와인을 페어링해 즐길 수도 있다. 손종원 셰프가 이타닉가든과 라망시크레 모두 책임지고 있다.',
#      'readerReview': '',
#      'businessReview': ''},
#     'extraInfo': {'wineInputType': 'NO_CHECK',
#      'wineInputYesEtc': '',
#      'wineCorkageEtc': '',
#      'holidayYn': True,
#      'wineOrderYn': False,
#      'holidayType': None,
#      'holidayEtc': '',
#      'timeEtc': ''},
#     'tags': '',
#     'etcInfo': {'interior': '',
#      'seat': '',
#      'room': '',
#      'toilet': None,
#      'toiletEtc': '',
#      'chain': False,
#      'close': False,
#      'renewal': False,
#      'reviewerRecommend': False,
#      'onlySiteView': False,
#      'head': '',
#      'branch': ''},
#     'status': 'ACTIVE',
#     'buzUsername': '',
#     'brandMatchStatus': 'NORMAL',
#     'brandRejectReason': '',
#     'orderDescending': 128,
#     'foodTypeDetails': None,
#     'features': None,
#     'countEvaluate': 0,
#     'bookmark': False,
#     'workingHour': '현재 브레이크 타임<br/>18:00부터 영업 시작',
#     'hourInfoBreakEnd2Times': None,
#     'foodTypes': ['컨템포러리', '프랑스식'],
#     'foodDetailTypes': ['컨템포러리', '프랑스식'],
#     'feature107': False,
#     'brandBranches': [],
#     'expiredBusinessDate': True,
#     'brandHead': None,
#     'firstImage': {'createdDate': 1750985422000,
#      'url': '/images/es_bc57d8c54f184ae18723454b6cb5a950.jpg',
#      'orderAscending': 0},
#     'firstLogoImage': None,
#     '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29567'},
#      'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29567{?projection}',
#       'templated': True},
#      'childrenRestaurants': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29567/childrenRestaurants{?projection}',
#       'templated': True},
#      'holidayList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29567/holidayList'},
#      'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29567/relativeWriter'},
#      'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29567/evaluates'},
#      'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29567/restaurantFeatures'},
#      'menuList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29567/menuList'},
#      'businessOrders': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29567/businessOrders'},
#      'wineList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29567/wineList'},
#      'hourList': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29567/hourList'},
#      'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29567/reports'},
#      'parentRestaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29567/parentRestaurant{?projection}',
#       'templated': True},
#      'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29567/foodTypeCategories'}}}]},
#  '_links': {'first': {'href': 'https://www.bluer.co.kr/api/v1/restaurants?query=&foodType=&foodTypeDetail=&feature=&location=&locationDetail=&area=&areaDetail=&priceRange=&ribbonType=&recommended=false&isSearchName=false&tabMode=single&searchMode=ribbonType&zone1=&zone2=&zone2Lat=&zone2Lng=&page=0&size=30&sort=headerInfo.ribbonType,asc&sort=updatedDate,id,desc'},
#   'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants?query=&foodType=&foodTypeDetail=&feature=&location=&locationDetail=&area=&areaDetail=&priceRange=&ribbonType=&recommended=false&isSearchName=false&tabMode=single&searchMode=ribbonType&zone1=&zone2=&zone2Lat=&zone2Lng=&page=0&size=30&sort=headerInfo.ribbonType,asc&sort=updatedDate,id,desc'},
#   'next': {'href': 'https://www.bluer.co.kr/api/v1/restaurants?query=&foodType=&foodTypeDetail=&feature=&location=&locationDetail=&area=&areaDetail=&priceRange=&ribbonType=&recommended=false&isSearchName=false&tabMode=single&searchMode=ribbonType&zone1=&zone2=&zone2Lat=&zone2Lng=&page=1&size=30&sort=headerInfo.ribbonType,asc&sort=updatedDate,id,desc'},
#   'last': {'href': 'https://www.bluer.co.kr/api/v1/restaurants?query=&foodType=&foodTypeDetail=&feature=&location=&locationDetail=&area=&areaDetail=&priceRange=&ribbonType=&recommended=false&isSearchName=false&tabMode=single&searchMode=ribbonType&zone1=&zone2=&zone2Lat=&zone2Lng=&page=728&size=30&sort=headerInfo.ribbonType,asc&sort=updatedDate,id,desc'}},
#  'page': {'size': 30, 'totalElements': 21862, 'totalPages': 729, 'number': 0}}

# %% [markdown]
# ## 📊 CSV 파일
#
# **CSV (Comma-Separated Values)는** 엑셀처럼 표 형태의 데이터를 쉼표로 구분하여 저장하는 간단한 텍스트 파일 형식입니다.

# %% [markdown]
# ### 기본 CSV 처리

# %%
students_data = [
    ['이름', '나이', '전공', '학점'],
    ['김철수', 20, '컴퓨터공학', 3.8],
    ['이영희', 19, '경영학', 4.2],
    ['박민수', 21, '수학과', 3.5],
    ['최지은', 20, '영어영문학', 4.0]
]

# %%
# CSV 파일 쓰기
import csv

with open('students.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerows(students_data)

print("students.csv 파일 생성 완료!")
# Out:
# students.csv 파일 생성 완료!

# %%
# CSV 파일 읽기
with open('students.csv', 'r', encoding='utf-8') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['이름', '나이', '전공', '학점']
# ['김철수', '20', '컴퓨터공학', '3.8']
# ['이영희', '19', '경영학', '4.2']
# ['박민수', '21', '수학과', '3.5']
# ['최지은', '20', '영어영문학', '4.0']

# %% [markdown]
# ### DictReader와 DictWriter 활용

# %%
# 딕셔너리 형태의 데이터
products = [
    {'제품명': '노트북', '가격': 1200000, '재고': 15, '카테고리': '전자제품'},
    {'제품명': '마우스', '가격': 25000, '재고': 50, '카테고리': '전자제품'},
    {'제품명': '키보드', '가격': 80000, '재고': 30, '카테고리': '전자제품'},
    {'제품명': '모니터', '가격': 300000, '재고': 8, '카테고리': '전자제품'}
]

# %%
# DictWriter로 CSV 파일 쓰기
with open('products.csv', 'w', newline='', encoding='utf-8') as file:
    fieldnames = ['제품명', '가격', '재고', '카테고리']
    writer = csv.DictWriter(file, fieldnames=fieldnames)

    writer.writeheader()  # 헤더 행 쓰기
    writer.writerows(products)  # 데이터 행들 쓰기

print("products.csv 파일 생성 완료!")
# Out:
# products.csv 파일 생성 완료!

# %%
# DictReader로 CSV 파일 읽기
with open('products.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)

    print("=== 제품 목록 ===")
    for row in reader:
        print(f"제품: {row['제품명']}")
        print(f"가격: {int(row['가격']):,}원")
        print(f"재고: {row['재고']}개")
        print(f"카테고리: {row['카테고리']}")
        print("-" * 20)
# Out:
# === 제품 목록 ===
# 제품: 노트북
# 가격: 1,200,000원
# 재고: 15개
# 카테고리: 전자제품
# --------------------
# 제품: 마우스
# 가격: 25,000원
# 재고: 50개
# 카테고리: 전자제품
# --------------------
# 제품: 키보드
# 가격: 80,000원
# 재고: 30개
# 카테고리: 전자제품
# --------------------
# 제품: 모니터
# 가격: 300,000원
# 재고: 8개
# 카테고리: 전자제품
# --------------------

# %% [markdown]
# ### pandas를 활용한 데이터 처리
#
# **pandas는**데이터 분석과 조작을 위한 파이썬 라이브러리로, 엑셀처럼 표 형태의 데이터를 쉽게 다룰 수 있게 해줍니다.

# %%
# 제품 데이터
products = [
    {'제품명': '노트북', '가격': 1200000, '재고': 15, '카테고리': '전자제품'},
    {'제품명': '마우스', '가격': 25000, '재고': 50, '카테고리': '전자제품'},
    {'제품명': '키보드', '가격': 80000, '재고': 30, '카테고리': '전자제품'},
    {'제품명': '모니터', '가격': 300000, '재고': 8, '카테고리': '전자제품'}
]

# %%
import pandas as pd

# DataFrame 생성 (pandas에서 다루는 표 형태 데이터)
df_products = pd.DataFrame(products)
df_products
# Out:
#    제품명       가격  재고  카테고리
# 0  노트북  1200000  15  전자제품
# 1  마우스    25000  50  전자제품
# 2  키보드    80000  30  전자제품
# 3  모니터   300000   8  전자제품

# %%
# CSV 파일로 저장 (한글 깨짐 방지를 위해 utf-8-sig 사용)
df_products.to_csv('제품목록.csv', encoding='utf-8-sig', index=False)
print("제품목록.csv 파일 저장 완료!")
# Out:
# 제품목록.csv 파일 저장 완료!

# %%
# 저장된 CSV 파일 다시 읽기
df_loaded = pd.read_csv('제품목록.csv', encoding='utf-8-sig')
df_loaded
# Out:
#    제품명       가격  재고  카테고리
# 0  노트북  1200000  15  전자제품
# 1  마우스    25000  50  전자제품
# 2  키보드    80000  30  전자제품
# 3  모니터   300000   8  전자제품

# %% [markdown]
# - **`pd.DataFrame()`**: 딕셔너리 리스트를 표 형태로 자동 변환
# - **`encoding='utf-8-sig'`**: 엑셀에서 한글이 깨지지 않도록 하는 인코딩
# - **`index=False`**: 행 번호(0,1,2,3...)를 CSV에 저장하지 않음

# %% [markdown]
# ### JSON vs CSV 비교
#
# | 구분 | JSON | CSV |
# | --- | --- | --- |
# | **가독성** | 사람이 읽기 좋음 | 표 형태로 직관적 |
# | **데이터 구조** | 중첩 구조 지원 | 평면적 구조만 지원 |
# | **파일 크기** | 상대적으로 큼 | 상대적으로 작음 |
# | **Excel 호환** | 불가능 | 가능 |
# | **웹 API** | 표준 형식 | 거의 사용 안함 |
# | **사용 예시** | 설정 파일, API 응답 | 데이터 분석, 보고서 |
